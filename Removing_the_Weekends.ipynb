# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/content/results_summary (3).csv')

df.head()
# Out:
#          Date  Original_peak  Reduced_peak  Reduction_kW
# 0  2024-04-30    1087.488333   1087.488333      0.000000
# 1  2024-05-01    1014.698333   1014.698333      0.000000
# 2  2024-05-02    1077.131667   1041.055377     36.076290
# 3  2024-05-03    1012.855000   1012.738029      0.116971
# 4  2024-05-04     475.508333    475.508333      0.000000

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

filtered_df = df[df['Original_peak'] > 800]

# print(filtered_df)

is_zeroes = (filtered_df['Reduction_kW'] == 0).sum()

print(is_zeroes)
# Out:
# 59

# %%
filtered_df.shape
# Out:
# (198, 3)

# %%
filtered_df.to_csv('results_summary.csv')
