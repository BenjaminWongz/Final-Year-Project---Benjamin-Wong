# %% [markdown]
# #**1. Data Processing and Feature Engineering for AI Model 😎😎**

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **1.1 Resampling the data and Combining weather data**

# %%
# Data Processing for the AI model

import pandas as pd
import numpy as np
import holidays

# Getting the Dataset
df = pd.read_csv('combine_1.csv')

# Chaging the Time Column into Timestamp making it data_time for other processing
df.rename(columns = {'Time' : 'Timestamp'}, inplace = True)
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df.set_index('Timestamp', inplace=True)

df_short = df.copy()

# Resampling the data into 15 minutues (average value)
df2 = df.resample('15min').mean()

# %%
# *** Obtaining the Weather Conditions from open-meteo API *** --> To inrease the accuracy of the AI model we need to give it more inputs to understand more patterns
import pandas as pd
import requests


# Copy the API URL address
api_url = "https://historical-forecast-api.open-meteo.com/v1/forecast?latitude=3.04&longitude=101.79&start_date=2023-04-03&end_date=2025-02-21&hourly=temperature_2m,relative_humidity_2m,apparent_temperature,cloud_cover,shortwave_radiation"

# Making request to the API
response = requests.get(api_url)
weather_data_json = response.json()

# Convert the JSON response to a pandas DataFrame
weather_df = pd.DataFrame(weather_data_json['hourly'])

# Convert the 'time' column to a proper dataframe object and set it as index
weather_df['time'] = pd.to_datetime(weather_df['time'])
weather_df.set_index('time', inplace = True)

# Resampling and using interpolation to fill up the data in terms of 15 minutes, because we only have hourly   data
weather_df_5mins = weather_df.resample('1min').interpolate(method = 'time')

print('Weather Data is successfully obtained and converted to a Dataframe, ready to be added to the main dataframe')
weather_df_5mins.head()

# *** Merging the Weather Data and the Power Consumption Data ***
df_combined = df_short.join(weather_df_5mins)
df_combined.drop(columns = ['cloud_cover', 'shortwave_radiation', 'relative_humidity_2m'], inplace = True)

# Clean the temperature data before doing any other processing
df_combined['temperature_2m'].interpolate(method='linear', inplace=True)
df_combined['apparent_temperature'].interpolate(method='linear', inplace=True)


# Verifying the merge of data
print(df_combined.head())
# Out:
# Weather Data is successfully obtained and converted to a Dataframe, ready to be added to the main dataframe
#                        Pt(kW)   St(kVA)  temperature_2m  apparent_temperature
# Timestamp
# 2023-04-03 00:00:00   99.3316  109.5088       24.500000                 30.50
# 2023-04-03 00:01:00  101.1692  111.2588       24.506667                 30.51
# 2023-04-03 00:02:00  102.3316  112.2588       24.513333                 30.52
# 2023-04-03 00:03:00  102.4148  112.3252       24.520000                 30.53
# 2023-04-03 00:04:00  100.8152  111.0088       24.526667                 30.54
# /tmp/ipython-input-327006817.py:31: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_combined['temperature_2m'].interpolate(method='linear', inplace=True)
# /tmp/ipython-input-327006817.py:32: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_combined['apparent_temperature'].interpolate(method='linear', inplace=True)

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **1.2 Features Engineering, extracting information from the the timetamp**

# %%
# Calendar Features
df_combined['day_of_week'] = df_combined.index.day_of_week
# malaysia_holidays = holidays.MY()
# df_combined['is_holiday'] = df_combined.index.isin(malaysia_holidays).astype(int)
# df_combined['is_weekend'] = (df_combined['day_of_week'] == 5) | (df_combined['day_of_week'] == 6)
# df_combined['is_weekend'] = df_combined['is_weekend'].astype(int)

# Getting the Time-Based Features
df_combined['hour_of_day'] = df_combined.index.hour
df_combined['minute_of_day']= df_combined.index.minute

# Using sin and cos for periodicity (15 minutes) --> Cylical Features for better model training
intervals_per_day = 24 * 60
df_combined['intervals_of_day'] = (df_combined['hour_of_day'] * 60 ) + (df_combined['minute_of_day'])
df_combined['intervals_sin'] = np.sin(2 * np.pi * df_combined['intervals_of_day'] / intervals_per_day)
df_combined['intervals_cos'] = np.cos(2 * np.pi * df_combined['intervals_of_day'] / intervals_per_day)

# Adding week of semester as an additional feature
# academic_periods = [
#     {'start' : '2024-01-29', 'end' : '2024-05-05', 'type': 'lecture'},
#     {'start' : '2024-05-06', 'end' : '2024-05-26', 'type' : 'exam'},
#     {'start' : '2024-05-27', 'end' : '2024-06-16', 'type' : 'break'},
#     {'start' : '2024-06-17', 'end' : '2024-09-22', 'type' : 'lecture'},
#     {'start' : '2024-09-23', 'end' : '2024-10-13', 'type' : 'exam'},
#     {'start' : '2024-10-14', 'end' : '2024-10-27', 'type' : 'break'},
#     {'start' : '2024-10-28', 'end' : '2024-12-15', 'type' : 'lecture'},
#     {'start' : '2024-12-16', 'end' : '2025-01-05', 'type' : 'exam'},
#     {'start' : '2025-01-06', 'end' : '2025-02-09', 'type' : 'break'},
#     {'start': '2025-02-10', 'end' : '2025-05-18', 'type' : 'lecture'}
# ]

# for period in academic_periods:
#   period['start'] = pd.to_datetime(period['start']).normalize()
#   period['end'] = pd.to_datetime(period['end']).normalize()

# def get_semester_week(date):
#   """
#   Returns the lecture week number (1-14/16) if the date is in a lecture period.
#   Otherwise, returns 0.
#   """
#   normalized_date = date.normalize()
#   for period in academic_periods:
#     if period['type'] == 'lecture' and period['start'] <= normalized_date <= period['end']:
#       week_number = (normalized_date - period['start']).days // 7 + 1
#       return week_number
#   return 0

# def is_exam_period(date):
#   """
#   Returns 1 if the date is in an exam period, 0 otherwise.
#   """
#   normalized_date = date.normalize()
#   for period in academic_periods:
#     if period['type'] == 'exam' and period['start'] <= normalized_date <= period['end']:
#       return 1

#   return 0

# df_combined['week_of_semester'] = df_combined.index.to_series().apply(get_semester_week)
# df_combined['is_exam_period'] = df_combined.index.to_series().apply(is_exam_period)


# Dropping the temporary features
columns_to_drop = ['hour_of_day', 'minute_of_day', 'intervals_of_day', 'St(kVA)']
df_combined.drop(columns = columns_to_drop, inplace = True)

# Function to create lagging features for the blocks of date due to gaps in the data
def create_lag_features(df, data_columns = ['Pt(kW)']):
  # Takes the continuous dataframe and adds the previous features
  df_featured = df.copy()

  # Adding the lagging features
  df_featured['load_t-1m'] = df_featured[data_columns].shift(1)
  df_featured['load_t-5m'] = df_featured[data_columns].shift(5)
  df_featured['load_t-15m'] = df_featured[data_columns].shift(15)
  df_featured['load_t-30m'] = df_featured[data_columns].shift(30)
  df_featured['load_t-1h'] = df_featured[data_columns].shift(60)
  df_featured['load_same_time_last_week'] = df_featured[data_columns].shift(1440 * 7)
  df_featured['load_t-24h'] = df_featured[data_columns].shift(1440)
  df_featured['load_t-48h'] = df_featured[data_columns].shift(1440 * 2)
  df_featured['load_t-72h'] = df_featured[data_columns].shift(1440 * 3)

  return df_featured

# %%
# Defining the blocks based on the gaps of data to ensure continuity of timestamp

# Block 1 is from 03-04-2023 to 20-04-2023
block_1 = df_combined.loc[:'2023-04-20']

# Block 2 is from 25-04-2023 to 05-06-2023
block_2 = df_combined.loc['2023-04-25' : '2023-06-05']

# Block 3 is from 12-07-2023 to 21-07-2023
block_3 = df_combined.loc['2023-06-12' : '2023-07-21']

# Block 4 is from 24-07-2023 to 26-07-2023
block_4 = df_combined.loc['2023-07-24' : '2023-07-26']

# Block 5 is from 28-07-2023 to 08-09-2023
block_5 = df_combined.loc['2023-07-28' : '2023-09-08']

# Block 6 is from 10-09-2023 to 11-09-2023
block_6 = df_combined.loc['2023-09-10' : '2023-09-11']

# Block 7 is from 20-09-2023 to 20-10-2023
block_7 = df_combined.loc['2023-09-20' : '2023-10-20']

# Block 8 is from 23-10-2023 to 30-10-2023
block_8 = df_combined.loc['2023-10-23' : '2023-10-30']

# Block 8 is from 01-11-2023 to 04-01-2024
block_9 = df_combined.loc['2023-11-01' : '2024-01-04']

# Block 9 is from 10-01-2024 to 19-01-2024
block_10 = df_combined.loc['2024-01-10' : '2024-01-19']

# Block 10 is from 22-01-2024 onwards
block_11 = df_combined.loc['2024-01-22' : '2024-12-10' ]

# Block 11 is from 12-12-2024 onwards
block_12 = df_combined.loc['2024-12-12':]

# Create the lagging features (15 mins and the past week) separately
processed_block_1 = create_lag_features(block_1)
processed_block_2 = create_lag_features(block_2)
processed_block_3 = create_lag_features(block_3)
processed_block_4 = create_lag_features(block_4)
processed_block_5 = create_lag_features(block_5)
processed_block_6 = create_lag_features(block_6)
processed_block_7 = create_lag_features(block_7)
processed_block_8 = create_lag_features(block_8)
processed_block_9 = create_lag_features(block_9)
processed_block_10 = create_lag_features(block_10)
processed_block_11 = create_lag_features(block_11)
processed_block_12 = create_lag_features(block_12)

# Creating a list of the processed blocks
all_processed_blocks = [processed_block_1, processed_block_2, processed_block_3, processed_block_4, processed_block_5, processed_block_6, processed_block_7, processed_block_8, processed_block_9, processed_block_10, processed_block_11, processed_block_12]

# Concatenate all the blocks into one so that it can be put into one LSTM Model for training
df_with_nans = pd.concat(all_processed_blocks)

# Dropping all the rows with NaN values once on the final DataFrame
df_final = df_with_nans.dropna()

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **1.3 Splitting the data into training and testing set (80% split)**

# %%
# *** From this stage, we are preparing the AI model training ***

# Importing the necessary libraries to perform the AI model training
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input
import matplotlib.pyplot as plt

# Reshaping the dataframe into numpy arrays for Analysis later --> The format that LSTM accepts
# The Target Column is the Pt(kW) --> This is the column that we want to predict and this is the Y-axis or the dependent variable
data_column = 'Pt(kW)'

# The y is the column that we want to predict --> The dependent variable
y = df_final[data_column]

# The X is the columns or the features that we want to use as input
X = df_final.drop(columns = [data_column])

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (839520, 14)
# Shape of y: (839520,)

# %%
# Data Processing for the AI model

import pandas as pd
import numpy as np
import holidays

# Getting the Dataset
df1 = pd.read_csv('combine_1.csv')

# Chaging the Time Column into Timestamp making it data_time for other processing
df1.rename(columns = {'Time' : 'Timestamp'}, inplace = True)
df1['Timestamp'] = pd.to_datetime(df1['Timestamp'])
df1.set_index('Timestamp', inplace=True)

# Resampling the data into 15 minutues (average value)
df1 = df1.resample('15min').mean()

# *** Obtaining the Weather Conditions from open-meteo API *** --> To inrease the accuracy of the AI model we need to give it more inputs to understand more patterns
import pandas as pd
import requests


# Copy the API URL address
api_url = "https://historical-forecast-api.open-meteo.com/v1/forecast?latitude=3.04&longitude=101.79&start_date=2023-04-03&end_date=2025-02-21&hourly=temperature_2m,relative_humidity_2m,apparent_temperature,cloud_cover,shortwave_radiation"

# Making request to the API
response = requests.get(api_url)
weather_data_json = response.json()

# Convert the JSON response to a pandas DataFrame
weather_df = pd.DataFrame(weather_data_json['hourly'])

# Convert the 'time' column to a proper dataframe object and set it as index
weather_df['time'] = pd.to_datetime(weather_df['time'])
weather_df.set_index('time', inplace = True)

# Resampling and using interpolation to fill up the data in terms of 15 minutes, because we only have hourly data
weather_df_15mins = weather_df.resample('15min').interpolate(method = 'time')

print('Weather Data is successfully obtained and converted to a Dataframe, ready to be added to the main dataframe')
weather_df_15mins.head()

# *** Merging the Weather Data and the Power Consumption Data ***
df_combined = df1.join(weather_df_15mins)
df_combined.drop(columns = ['cloud_cover', 'shortwave_radiation', 'relative_humidity_2m'], inplace = True)

# Verifying the merge of data
print(df_combined.head())

# Making request to the API
response = requests.get(api_url)
weather_data_json = response.json()

# Convert the JSON response to a pandas DataFrame
weather_df = pd.DataFrame(weather_data_json['hourly'])

# Convert the 'time' column to a proper dataframe object and set it as index
weather_df['time'] = pd.to_datetime(weather_df['time'])
weather_df.set_index('time', inplace = True)

# Resampling and using interpolation to fill up the data in terms of 15 minutes, because we only have hourly data
weather_df_15mins = weather_df.resample('15min').interpolate(method = 'time')

print('Weather Data is successfully obtained and converted to a Dataframe, ready to be added to the main dataframe')
weather_df_15mins.head()

# *** Merging the Weather Data and the Power Consumption Data ***
df_combined1 = df1.join(weather_df_15mins)
df_combined1.drop(columns = ['cloud_cover', 'shortwave_radiation', 'relative_humidity_2m'], inplace = True)

# Verifying the merge of data
print(df_combined1.head())

# Calendar Features
malaysia_holidays = holidays.MY()
df_combined1['day_of_week'] = df_combined1.index.day_of_week
df_combined1['is_holiday'] = df_combined1.index.isin(malaysia_holidays).astype(int)
df_combined1['is_weekend'] = (df_combined1['day_of_week'] == 5) | (df_combined1['day_of_week'] == 6)
df_combined1['is_weekend'] = df_combined1['is_weekend'].astype(int)

# Getting the Time-Based Features
df_combined1['hour_of_day'] = df_combined1.index.hour
df_combined1['minute_of_day']= df_combined1.index.minute

# Using sin and cos for periodicity (15 minutes) --> Cylical Features for better model training
intervals_per_day = 24 * 4
df_combined1['intervals_of_day'] = (df_combined1['hour_of_day'] * 4) + (df_combined1['minute_of_day'] / 15)
df_combined1['intervals_sin'] = np.sin(2 * np.pi * df_combined1['intervals_of_day'] / intervals_per_day)
df_combined1['intervals_cos'] = np.cos(2 * np.pi * df_combined1['intervals_of_day'] / intervals_per_day)

# Adding week of semester as an additional feature
academic_periods = [
    {'start' : '2024-01-29', 'end' : '2024-05-05', 'type': 'lecture'},
    {'start' : '2024-05-06', 'end' : '2024-05-26', 'type' : 'exam'},
    {'start' : '2024-05-27', 'end' : '2024-06-16', 'type' : 'break'},
    {'start' : '2024-06-17', 'end' : '2024-09-22', 'type' : 'lecture'},
    {'start' : '2024-09-23', 'end' : '2024-10-13', 'type' : 'exam'},
    {'start' : '2024-10-14', 'end' : '2024-10-27', 'type' : 'break'},
    {'start' : '2024-10-28', 'end' : '2024-12-15', 'type' : 'lecture'},
    {'start' : '2024-12-16', 'end' : '2025-01-05', 'type' : 'exam'},
    {'start' : '2025-01-06', 'end' : '2025-02-09', 'type' : 'break'},
    {'start': '2025-02-10', 'end' : '2025-05-18', 'type' : 'lecture'}
]

for period in academic_periods:
  period['start'] = pd.to_datetime(period['start']).normalize()
  period['end'] = pd.to_datetime(period['end']).normalize()

def get_semester_week(date):
  """
  Returns the lecture week number (1-14/16) if the date is in a lecture period.
  Otherwise, returns 0.
  """
  normalized_date = date.normalize()
  for period in academic_periods:
    if period['type'] == 'lecture' and period['start'] <= normalized_date <= period['end']:
      week_number = (normalized_date - period['start']).days // 7 + 1
      return week_number
  return 0

def is_exam_period(date):
  """
  Returns 1 if the date is in an exam period, 0 otherwise.
  """
  normalized_date = date.normalize()
  for period in academic_periods:
    if period['type'] == 'exam' and period['start'] <= normalized_date <= period['end']:
      return 1

  return 0

df_combined1['week_of_semester'] = df_combined1.index.to_series().apply(get_semester_week)
df_combined1['is_exam_period'] = df_combined1.index.to_series().apply(is_exam_period)


# Dropping the temporary features
columns_to_drop = ['hour_of_day', 'minute_of_day', 'intervals_of_day', 'St(kVA)']
df_combined1.drop(columns = columns_to_drop, inplace = True)

# Function to create lagging features for the blocks of date due to gaps in the data
def create_lag_features(df, data_columns = ['Pt(kW)']):
  # Takes the continuous dataframe and adds the previous features
  df_featured = df.copy()

  # Adding the lagging features
  df_featured['load_t-15m'] = df_featured[data_columns].shift(1)
  df_featured['load_t-30m'] = df_featured[data_columns].shift(2)
  df_featured['load_t-45m'] = df_featured[data_columns].shift(3)
  df_featured['load_t-1h'] = df_featured[data_columns].shift(4)
  df_featured['load_same_time_last_week'] = df_featured[data_columns].shift(96 * 7)
  df_featured['load_t-24h'] = df_featured[data_columns].shift(96)
  df_featured['load_t-48h'] = df_featured[data_columns].shift(192)
  df_featured['load_t-72h'] = df_featured[data_columns].shift(288)

  return df_featured.dropna()

# Defining the blocks based on the gaps of data to ensure continuity of timestamp

# Block 1 is from 03-04-2023 to 20-04-2023
block_1 = df_combined1.loc[:'2023-04-20']

# Block 2 is from 25-04-2023 to 05-06-2023
block_2 = df_combined1.loc['2023-04-25' : '2023-06-05']

# Block 3 is from 12-07-2023 to 21-07-2023
block_3 = df_combined1.loc['2023-06-12' : '2023-07-21']

# Block 4 is from 24-07-2023 to 26-07-2023
block_4 = df_combined1.loc['2023-07-24' : '2023-07-26']

# Block 5 is from 28-07-2023 to 08-09-2023
block_5 = df_combined1.loc['2023-07-28' : '2023-09-08']

# Block 6 is from 10-09-2023 to 11-09-2023
block_6 = df_combined1.loc['2023-09-10' : '2023-09-11']

# Block 7 is from 20-09-2023 to 20-10-2023
block_7 = df_combined1.loc['2023-09-20' : '2023-10-20']

# Block 8 is from 23-10-2023 to 30-10-2023
block_8 = df_combined1.loc['2023-10-23' : '2023-10-30']

# Block 8 is from 01-11-2023 to 04-01-2024
block_9 = df_combined1.loc['2023-11-01' : '2024-01-04']

# Block 9 is from 10-01-2024 to 19-01-2024
block_10 = df_combined1.loc['2024-01-10' : '2024-01-19']

# Block 10 is from 22-01-2024 onwards
block_11 = df_combined1.loc['2024-01-22' : '2024-12-10' ]

# Block 11 is from 12-12-2024 onwards
block_12 = df_combined1.loc['2024-12-12':]

# Create the lagging features (15 mins and the past week) separately
processed_block_1 = create_lag_features(block_1)
processed_block_2 = create_lag_features(block_2)
processed_block_3 = create_lag_features(block_3)
processed_block_4 = create_lag_features(block_4)
processed_block_5 = create_lag_features(block_5)
processed_block_6 = create_lag_features(block_6)
processed_block_7 = create_lag_features(block_7)
processed_block_8 = create_lag_features(block_8)
processed_block_9 = create_lag_features(block_9)
processed_block_10 = create_lag_features(block_10)
processed_block_11 = create_lag_features(block_11)
processed_block_12 = create_lag_features(block_12)

# Creating a list of the processed blocks
all_processed_blocks = [processed_block_1, processed_block_2, processed_block_3, processed_block_4, processed_block_5, processed_block_6, processed_block_7, processed_block_8, processed_block_9, processed_block_10, processed_block_11, processed_block_12]

# Concatenate all the blocks into one so that it can be put into one LSTM Model for training
df_final1 = pd.concat(all_processed_blocks)
# Out:
# Weather Data is successfully obtained and converted to a Dataframe, ready to be added to the main dataframe
#                          Pt(kW)     St(kVA)  temperature_2m  \
# Timestamp
# 2023-04-03 00:00:00  102.181040  112.219760            24.5
# 2023-04-03 00:15:00  101.205547  111.813920            24.6
# 2023-04-03 00:30:00  101.452853  111.673440            24.7
# 2023-04-03 00:45:00  102.504933  113.004240            24.8
# 2023-04-03 01:00:00  100.501093  110.474853            24.9
#
#                      apparent_temperature
# Timestamp
# 2023-04-03 00:00:00                 30.50
# 2023-04-03 00:15:00                 30.65
# 2023-04-03 00:30:00                 30.80
# 2023-04-03 00:45:00                 30.95
# 2023-04-03 01:00:00                 31.10
# Weather Data is successfully obtained and converted to a Dataframe, ready to be added to the main dataframe
#                          Pt(kW)     St(kVA)  temperature_2m  \
# Timestamp
# 2023-04-03 00:00:00  102.181040  112.219760            24.5
# 2023-04-03 00:15:00  101.205547  111.813920            24.6
# 2023-04-03 00:30:00  101.452853  111.673440            24.7
# 2023-04-03 00:45:00  102.504933  113.004240            24.8
# 2023-04-03 01:00:00  100.501093  110.474853            24.9
#
#                      apparent_temperature
# Timestamp
# 2023-04-03 00:00:00                 30.50
# 2023-04-03 00:15:00                 30.65
# 2023-04-03 00:30:00                 30.80
# 2023-04-03 00:45:00                 30.95
# 2023-04-03 01:00:00                 31.10

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **1.4 Creating the Multi-Step Sequences**

# %%
# *** Preparing the New Data Separation - Creating (History -> Future) Pairs ***
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def create_multi_step_sequence(data, n_steps_in, n_steps_out):
  """
  Converts the time series data into input (history) and output (future) windows
  """
  X, y = [], []
  for i in range(len(data)):
    # Finding the end of the pattern
    end_ix = i + n_steps_in
    out_end_ix = end_ix + n_steps_out

    # Checking if we are beyond the dataset
    if out_end_ix > len(data):
      break

    # Gather the input and output parts of the pattern
    seq_x, seq_y = data[i:end_ix], data[end_ix : out_end_ix]
    X.append(seq_x)
    y.append(seq_y)

  return np.array(X), np.array(y)

# --- Defining the window size ---
# First, we are using the past 96 points to predict the next 24 hours
n_lookback = 30
n_forecast = 5

# --- Creating the full dataset for sequencing ---
data_for_sequencing = df_final.copy()

# The first column should be our target variable 'Pt(kW)' for this to work easily
cols = [data_column] + [col for col in df_final if col != data_column]
data_for_sequencing = data_for_sequencing[cols]

# --- Split Train / Test BEFORE creating the sequences to prevent data leakages ---
# Define your split date
split_date = '2024-04-30'

# Create the training set (all data BEFORE the split date)
train_data = data_for_sequencing[data_for_sequencing.index < split_date]

# Create the test set (all data ON and AFTER the split date)
test_data = data_for_sequencing[data_for_sequencing.index >= split_date]

# --- Scaling the data ---
scaler = MinMaxScaler()
scaler.fit(train_data)

# Transform both the train and test data
train_scaled = scaler.transform(train_data)
test_scaled = scaler.transform(test_data)

# --- Creating the final X and y sequences ---
X_train, y_train = create_multi_step_sequence(train_scaled, n_lookback, n_forecast)
X_test, y_test = create_multi_step_sequence(test_scaled, n_lookback, n_forecast)

# The 'y' data contains all the features, but we only want to predict the first column --> Pt(kW)
y_train = y_train[:, :, 0]
y_test = y_test[:, :, 0]

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (421886, 30, 15)
# Shape of y_train: (421886, 5)
# Shape of X_test: (417566, 30, 15)
# Shape of y_test: (417566, 5)

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# # **2. Defining the Model Architecture and Training the AI Model 💪💪**

# %%
from tensorflow.keras.layers import GRU, Dropout

# Assume n_lookback=60, n_features=(your number), n_forecast=15

n_features = X_train.shape[2]
n_forecast = 5

# Define the model
tactical_model = Sequential(name="Tactical_15min_GRU")
tactical_model.add(Input(shape=(n_lookback, n_features)))

# A GRU layer is fast and effective for this shorter task
tactical_model.add(GRU(units=100, activation='tanh'))
tactical_model.add(Dropout(0.2))

# Output layer has 15 neurons for the 15-minute forecast
tactical_model.add(Dense(units=n_forecast))

tactical_model.compile(optimizer='adam', loss='mean_absolute_error')
tactical_model.summary()
# Out:
# Model: "Tactical_15min_GRU"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        34,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 5)              │           505 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,705 (135.57 KB)
#  Trainable params: 34,705 (135.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 15, restore_best_weights= True)
history = tactical_model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data = (X_test, y_test), callbacks = [early_stopping])
# Out:
# Epoch 1/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 89s 7ms/step - loss: 0.0249 - val_loss: 0.0093
# Epoch 2/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0158 - val_loss: 0.0101
# Epoch 3/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0156 - val_loss: 0.0102
# Epoch 4/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0155 - val_loss: 0.0097
# Epoch 5/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0154 - val_loss: 0.0093
# Epoch 6/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0153 - val_loss: 0.0091
# Epoch 7/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0153 - val_loss: 0.0090
# Epoch 8/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0153 - val_loss: 0.0100
# Epoch 9/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0152 - val_loss: 0.0088
# Epoch 10/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0151 - val_loss: 0.0099
# Epoch 11/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0152 - val_loss: 0.0093
# Epoch 12/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0151 - val_loss: 0.0088
# Epoch 13/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0151 - val_loss: 0.0093
# Epoch 14/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0150 - val_loss: 0.0091
# Epoch 15/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0150 - val_loss: 0.0091
# Epoch 16/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0507 - val_loss: 0.0256
# Epoch 17/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0305 - val_loss: 0.0110
# Epoch 18/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0194 - val_loss: 0.0104
# Epoch 19/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0175 - val_loss: 0.0113
# Epoch 20/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0205 - val_loss: 0.0226
# Epoch 21/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0223 - val_loss: 0.0175
# Epoch 22/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0241 - val_loss: 0.0131
# Epoch 23/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0236 - val_loss: 0.0306
# Epoch 24/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0435 - val_loss: 0.0177
# Epoch 25/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - loss: 0.0244 - val_loss: 0.0137
# Epoch 26/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 86s 6ms/step - loss: 0.0249 - val_loss: 0.0168
# Epoch 27/100
# 13184/13184 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - loss: 0.0227 - val_loss: 0.0190

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **2.1 Setting up the model architecture and training the AI model**

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Input, Dropout

# Use this new architecture with your Direct Multi-Step data
# n_lookback = 96, n_features = (your number), n_forecast = 96

model = Sequential()
model.add(Input(shape=(n_lookback, X_train.shape[2])))

# CNN layer to find local patterns in the input sequence
model.add(Conv1D(filters=64, kernel_size=5, activation='relu'))
# Optional: A pooling layer to summarize the findings
model.add(MaxPooling1D(pool_size=2))

# LSTM layer to understand the sequence of the patterns found by the CNN
model.add(LSTM(300, activation='tanh'))
model.add(Dropout(0.3))
model.add(Dense(n_forecast))

model.compile(optimizer='adam', loss='mean_absolute_error')
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 92, 64)         │         5,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 46, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 300)            │       438,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 300)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 96)             │        28,896 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 472,720 (1.80 MB)
#  Trainable params: 472,720 (1.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# --- Training the model ---
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 15, restore_best_weights= True)
history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data = (X_test, y_test), callbacks = [early_stopping])
# Out:
# Epoch 1/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - loss: 0.1127 - val_loss: 0.0665
# Epoch 2/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.0572 - val_loss: 0.0587
# Epoch 3/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0492 - val_loss: 0.0638
# Epoch 4/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0484 - val_loss: 0.0555
# Epoch 5/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0452 - val_loss: 0.0538
# Epoch 6/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0440 - val_loss: 0.0535
# Epoch 7/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.0440 - val_loss: 0.0558
# Epoch 8/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0430 - val_loss: 0.0545
# Epoch 9/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0422 - val_loss: 0.0514
# Epoch 10/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0420 - val_loss: 0.0526
# Epoch 11/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step - loss: 0.0419 - val_loss: 0.0602
# Epoch 12/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 0.0440 - val_loss: 0.0518
# Epoch 13/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0416 - val_loss: 0.0501
# Epoch 14/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0396 - val_loss: 0.0512
# Epoch 15/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0395 - val_loss: 0.0508
# Epoch 16/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0398 - val_loss: 0.0520
# Epoch 17/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0388 - val_loss: 0.0529
# Epoch 18/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0379 - val_loss: 0.0502
# Epoch 19/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0377 - val_loss: 0.0519
# Epoch 20/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0375 - val_loss: 0.0528
# Epoch 21/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0374 - val_loss: 0.0503
# Epoch 22/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0370 - val_loss: 0.0504
# Epoch 23/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0407 - val_loss: 0.0497
# Epoch 24/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0360 - val_loss: 0.0546
# Epoch 25/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0361 - val_loss: 0.0508
# Epoch 26/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0356 - val_loss: 0.0504
# Epoch 27/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0356 - val_loss: 0.0544
# Epoch 28/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0397 - val_loss: 0.0523
# Epoch 29/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0357 - val_loss: 0.0505
# Epoch 30/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0348 - val_loss: 0.0526
# Epoch 31/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0345 - val_loss: 0.0595
# Epoch 32/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - loss: 0.0366 - val_loss: 0.0521
# Epoch 33/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0342 - val_loss: 0.0496
# Epoch 34/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0342 - val_loss: 0.0526
# Epoch 35/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0339 - val_loss: 0.0515
# Epoch 36/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0336 - val_loss: 0.0494
# Epoch 37/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0337 - val_loss: 0.0500
# Epoch 38/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - loss: 0.0333 - val_loss: 0.0526
# Epoch 39/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - loss: 0.0333 - val_loss: 0.0514
# Epoch 40/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - loss: 0.0330 - val_loss: 0.0518
# Epoch 41/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0330 - val_loss: 0.0531
# Epoch 42/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 12s 12ms/step - loss: 0.0334 - val_loss: 0.0526
# Epoch 43/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0327 - val_loss: 0.0542
# Epoch 44/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0325 - val_loss: 0.0522
# Epoch 45/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - loss: 0.0326 - val_loss: 0.0517
# Epoch 46/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0321 - val_loss: 0.0521
# Epoch 47/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - loss: 0.0319 - val_loss: 0.0505
# Epoch 48/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 13s 12ms/step - loss: 0.0319 - val_loss: 0.0506
# Epoch 49/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 21s 13ms/step - loss: 0.0321 - val_loss: 0.0520
# Epoch 50/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 20s 13ms/step - loss: 0.0320 - val_loss: 0.0526
# Epoch 51/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - loss: 0.0317 - val_loss: 0.0632

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **2.2 Saving the model into Google Drive so that it can be retrieved**

# %%
# *** Saving the models and the scalers into Google Drive so that it can be called at any time ***

# Connecting Google Drive to this Colab Workspace

from google.colab import drive
print("Connecting to Google Drive")
drive.mount('/content/drive')
print ("Google Drive is connected successfully")


# Defining the full paths for the files that will be saved later
from pathlib import Path
import joblib

# Defining the project path
project_path = Path('/content/drive/MyDrive/FYP Project - Designing a controller to reduce peak demand')


model_path = project_path / 'short_term_prediction_1min.keras'
scaler_path = project_path / 'short_term_prediction_1min.pkl'


print(f"Model will be saved to {model_path}")
print(f"Scaler will be saved to {scaler_path}")
# import joblib # For saving the scalers

# Saving the keras model
tactical_model.save(model_path)

# Saving the scalers using joblib library
joblib.dump(scaler, scaler_path)

print("The models and the scalers are saved in the Google Drive successfully")
# Out:
# Connecting to Google Drive
# Mounted at /content/drive
# Google Drive is connected successfully
# Model will be saved to /content/drive/MyDrive/FYP Project - Designing a controller to reduce peak demand/short_term_prediction_1min.keras
# Scaler will be saved to /content/drive/MyDrive/FYP Project - Designing a controller to reduce peak demand/short_term_prediction_1min.pkl
# The models and the scalers are saved in the Google Drive successfully

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **2.3 Evaluating the performance of the model using graphical methods and finding the MAE**

# %%
from sklearn.metrics import mean_absolute_error
import matplotlib.pyplot as plt

# Assume 'model', 'scaler', 'X_test', and 'y_test' are ready from your training step

# --- Step 1: Make Predictions ---
# predictions_scaled will have a shape like (e.g., 11002, 96)
predictions_scaled = model.predict(X_test)


# --- Step 2: The Corrected Inverse Transform Logic ---
print("--- Inverse scaling the results ---")

# Get the number of samples and features for reshaping
n_test_samples = X_test.shape[0]
n_features = X_train.shape[2] # Number of columns in your original data

# --- Process the PREDICTIONS ---
# 1a. Create a dummy array with the right shape (all test predictions * all features)
dummy_pred = np.zeros((n_test_samples * n_forecast, n_features))
# 1b. Put the flattened predictions into the first column (the 'Pt(kW)' position)
dummy_pred[:, 0] = predictions_scaled.flatten()
# 1c. Inverse transform the entire dummy array
inversed_pred = scaler.inverse_transform(dummy_pred)
# 1d. Extract the first column and reshape it back to our (samples, 96) forecast format
predictions_kw = inversed_pred[:, 0].reshape(n_test_samples, n_forecast)


# --- Process the ACTUALS (y_test) in the exact same way for a fair comparison ---
# 2a. Create the dummy array for y_test
dummy_y = np.zeros((n_test_samples * n_forecast, n_features))
# 2b. Put the flattened y_test values into the first column
dummy_y[:, 0] = y_test.flatten()
# 2c. Inverse transform
inversed_y = scaler.inverse_transform(dummy_y)
# 2d. Extract and reshape
y_test_kw = inversed_y[:, 0].reshape(n_test_samples, n_forecast)


# --- Step 3: Calculate MAE and Plot Safely ---
print("\n--- Calculating Final Performance ---")

# Now we can safely calculate the MAE on the correctly scaled data
mae = mean_absolute_error(y_test_kw.flatten(), predictions_kw.flatten())
mape = np.mean(np.abs((y_test_kw - predictions_kw) / (y_test_kw + 1e-6))) * 100

print(f"Direct Multi-Step Model MAE: {mae:.2f} kW")
print(f"Direct Multi-Step Model MAPE: {mape:.2f}%")


# --- Plot the first prediction from the test set as an example ---
print("\n--- Plotting an example 24-hour forecast ---")

# Get the correct timestamps for our plot's x-axis
# This requires looking back at the original test_data DataFrame
plot_start_index = n_lookback + n_forecast - 1
plot_index = test_data.index[plot_start_index:plot_start_index + n_forecast]


plt.figure(figsize=(20, 8))
plt.plot(plot_index, y_test_kw[0], label='Actual Load')
plt.plot(plot_index, predictions_kw[0], label='Direct Forecast', linestyle='--')
plt.title('Sample 24-Hour Direct Multi-Step Forecast vs. Actual Load')
plt.xlabel('Time')
plt.ylabel('Power (kW)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# --- Inverse scaling the results ---
#
# --- Calculating Final Performance ---
# Direct Multi-Step Model MAE: 56.16 kW
# Direct Multi-Step Model MAPE: 18.82%
#
# --- Plotting an example 24-hour forecast ---

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error

# Assume you have these results from the previous step:
# y_test_kw (e.g., shape (11002, 96))
# predictions_kw (e.g., shape (11002, 96))

print("--- Calculating the MAE for each 24-hour forecast in the test set ---")

daily_maes = []
for i in range(len(y_test_kw)):
    # Calculate the MAE for the i-th 24-hour forecast
    day_mae = mean_absolute_error(y_test_kw[i], predictions_kw[i])
    daily_maes.append(day_mae)

# Create a new DataFrame to analyze these errors
evaluation_df = pd.DataFrame()
evaluation_df['mae_kw'] = daily_maes

print("Error analysis complete.")
print("\nDescription of daily errors:")
print(evaluation_df['mae_kw'].describe())
# Out:
# --- Calculating the MAE for each 24-hour forecast in the test set ---
# Error analysis complete.
#
# Description of daily errors:
# count    27792.000000
# mean        56.158990
# std         44.514598
# min          8.972060
# 25%         32.527261
# 50%         42.457983
# 75%         61.448904
# max        379.381604
# Name: mae_kw, dtype: float64

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **2.4 Plotting the predictions based on 96 samples (one day)**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates # Import the date formatting library
import pandas as pd

def plot_forecast(actuals, predictions, idx_to_plot, title=""):
    """
    Plots a single 24-hour forecast vs. the actual values with corrected time axis.
    """

    # --- THE FIX IS HERE ---
    # Instead of just the time, we create a full DatetimeIndex for a sample 24-hour period.
    # This gives matplotlib the context it needs to plot the data correctly.
    plot_index = pd.date_range(start="2024-01-01 00:00", periods=96, freq="15min")
    # --- END OF FIX ---

    plt.figure(figsize=(20, 8))

    # Plotting now uses the full DatetimeIndex for the x-axis
    plt.plot(plot_index, actuals[idx_to_plot], label='Actual Load', color='blue', linewidth=2)
    plt.plot(plot_index, predictions[idx_to_plot], label='Direct Forecast', color='red', linestyle='--', alpha=0.9)

    plt.title(f'{title} (Sample Index: {idx_to_plot})')
    plt.xlabel('Time of Day')
    plt.ylabel('Power (kW)')
    plt.legend()
    plt.grid(True)

    # --- FORMAT THE X-AXIS TO SHOW ONLY THE TIME ---
    # This formats the labels on the axis to look like 'HH:MM' (e.g., '08:00')
    ax = plt.gca()
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
    ax.xaxis.set_major_locator(mdates.HourLocator(interval=2)) # Set a major tick every 2 hours
    plt.gcf().autofmt_xdate() # Auto-formats the rotated labels to fit nicely

    plt.show()

# %%
# Find the index of the best (lowest MAE) and worst (highest MAE) forecasts
best_forecast_idx = evaluation_df['mae_kw'].idxmin()
worst_forecast_idx = evaluation_df['mae_kw'].idxmax()

# Find the index of a forecast that is close to the average (median) performance
median_mae = evaluation_df['mae_kw'].median()
# Find the index of the forecast whose MAE is closest to the median MAE
average_forecast_idx = (evaluation_df['mae_kw'] - median_mae).abs().idxmin()

print(f"\nBest forecast is at sample index: {best_forecast_idx} (MAE: {evaluation_df.loc[best_forecast_idx, 'mae_kw']:.2f} kW)")
print(f"Worst forecast is at sample index: {worst_forecast_idx} (MAE: {evaluation_df.loc[worst_forecast_idx, 'mae_kw']:.2f} kW)")
print(f"An average forecast is at sample index: {average_forecast_idx} (MAE: {evaluation_df.loc[average_forecast_idx, 'mae_kw']:.2f} kW)")
# Out:
# Best forecast is at sample index: 13994 (MAE: 7.07 kW)
# Worst forecast is at sample index: 25669 (MAE: 370.26 kW)
# An average forecast is at sample index: 15156 (MAE: 38.41 kW)

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **2.5 Choosing a day, make a prediction and compare with the actual results**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# === Step 1: Setup Your Test Scenario ===

# ==> YOUR ACTION: Choose any date you want to test from your dataset.
# Make sure the day BEFORE this date also exists in your data.
TARGET_DATE = '2024-04-30'

# Define the model parameters (these MUST match how your model was trained)
n_lookback = 96  # The history window (e.g., 24 hours)
n_forecast = 96  # The forecast window (e.g., 24 hours)
# Get the feature order from the scaler itself for robustness
feature_order = scaler.get_feature_names_out()
n_features = len(feature_order)
# Get the name of your target column (it's the first one in our setup)
data_column = feature_order[0]


# === Step 2: Prepare the Input Data (The Lookback Window) ===

print(f"--- Preparing input data for target date: {TARGET_DATE} ---")

# We need the full 24 hours of data from the day BEFORE our target date.
lookback_start_date = pd.to_datetime(TARGET_DATE) - pd.Timedelta(days=1)
lookback_start_str = lookback_start_date.strftime('%Y-%m-%d')

# Slice the lookback data from your main DataFrame
try:
    lookback_data = df_final.loc[lookback_start_str, feature_order]

    # Sanity check to make sure we have a full day of history
    if len(lookback_data) != n_lookback:
        print(f"⚠️ Warning: Lookback data for {lookback_start_str} is incomplete. It has {len(lookback_data)} rows instead of {n_lookback}.")
        # Handle this case if necessary, for now we will proceed

    print("✅ Input data successfully sliced.")

except KeyError:
    print(f"❌ Error: The historical data for {lookback_start_str} does not exist. Please choose a different target date.")
    # Stop the process if the data isn't there
    lookback_data = None


# === Step 3: Scale, Reshape, and Predict ===

if lookback_data is not None:
    # Scale the lookback data using the loaded scaler
    lookback_scaled = scaler.transform(lookback_data)

    # Reshape for the model: [1 sample, 96 timesteps, N features]
    input_for_model = lookback_scaled.reshape((1, n_lookback, n_features))

    # Make the 24-hour forecast in one shot
    print("--- Making prediction with the model ---")
    prediction_scaled = model.predict(input_for_model)


    # === Step 4: Inverse Scale and Format the Output ===

    # Use the dummy array trick to inverse transform the prediction
    dummy_pred = np.zeros((1 * n_forecast, n_features))
    dummy_pred[:, 0] = prediction_scaled.flatten()
    inversed_pred = scaler.inverse_transform(dummy_pred)

    # This is your final forecast in real kW values
    forecast_values = inversed_pred[:, 0]

    # Create a DataFrame for the forecast with the correct time index
    forecast_index = pd.date_range(start=TARGET_DATE, periods=96, freq='15min')
    forecast_df = pd.DataFrame({'Forecast': forecast_values}, index=forecast_index)
    print("✅ Forecast generated successfully.")


    # === Step 5: Compare with Actuals and Visualize ===

    # Get the actual values for the target day for comparison
    actual_load = df_final.loc[TARGET_DATE, data_column]

    # Calculate the MAE for this specific day
    mae = mean_absolute_error(actual_load, forecast_df['Forecast'])
    print(f"\n--- Results for {TARGET_DATE} ---")
    print(f"Mean Absolute Error (MAE): {mae:.2f} kW")

    # Plot the results
    plt.figure(figsize=(20, 8))
    plt.plot(actual_load, label='Actual Load', color='blue', linewidth=2)
    plt.plot(forecast_df['Forecast'], label='Direct Forecast', color='red', linestyle='--')
    plt.title(f'24-Hour Forecast vs. Actual Load for {TARGET_DATE}')
    plt.xlabel('Time')
    plt.ylabel('Power (kW)')
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# --- Preparing input data for target date: 2024-04-30 ---
# ✅ Input data successfully sliced.
# --- Making prediction with the model ---
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# ✅ Forecast generated successfully.
#
# --- Results for 2024-04-30 ---
# Mean Absolute Error (MAE): 18.42 kW

# %% [markdown]
# --------------------------------------------------------------------------------
# # **3. Peak Demand Reduction Controller** ⚡⚡

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **3.1 Loading the Pre-Trained Model for Forecasting Load Profile**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
from tensorflow.keras.models import load_model
from pathlib import Path

# Load the pre-trained models to be used later
from google.colab import drive
drive.mount('/content/drive')

# Defining the path for the files or the folders
project_folder = Path('/content/drive/MyDrive/FYP Project - Designing a controller to reduce peak demand')
strategy_model_path = project_folder / 'load_forecasting_lstm_model4.keras'
strategy_scaler_path = project_folder / 'scaler4.pkl'

tactical_model_path = project_folder / 'short_term_prediction_1min.keras'
tactical_scaler_path = project_folder / 'short_term_prediction_1min.pkl'

# Loading the models
strategic_model = load_model(strategy_model_path)
strategic_scaler = joblib.load(strategy_scaler_path)

tactical_model = load_model(tactical_model_path)
tactical_scaler = joblib.load(tactical_scaler_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **3.2 Setting up a RATIONING logic to adjust the threshold if the battery capacity is not enough**

# %%
def calculate_effective_threshold(
    forecasted_load,
    initial_threshold,
    available_energy_kwh,
    max_power_kw = 100.0, # Added parameter for maximum discharge power
    interval_hours = 1 / 60): # Changed default interval to 5 minutes

  """
  Calculates the optimal peak shaving threshold by checking if the rationing logic is needed --> or rather if the battery capacity that handle the entire duration without adjustment

  Returns:
    The final, effective threshold (in kW) to be used for the day.
  """

  # Identify all the intervals where the load is more than the threshold set
  peak_intervals = forecasted_load[forecasted_load > initial_threshold]

  # If there is no peak to reduce, do nothing
  if peak_intervals.empty:
    return initial_threshold

  # Calculate the power needed in each peak interval, capped by max_power_kw
  power_needed_in_peaks = (peak_intervals - initial_threshold).clip(upper=max_power_kw)


  # Calculating the entire energy that is needed to reduce the demand based on the initial threshold
  # Use the capped power for energy calculation
  energy_needed_kwh = power_needed_in_peaks.sum() * interval_hours


  # Check if the battery has enough capacity for the energy that is needed
  if energy_needed_kwh <= available_energy_kwh:
    print(f"Initial threshold {initial_threshold:.2f} kW is feasible with available energy {available_energy_kwh:.2f} kWh.")
    return initial_threshold

  effective_threshold = initial_threshold

  # A while loop to raise the threshold by 1kW and see if the battery has enough energy to cover the energy that is needed
  while energy_needed_kwh > available_energy_kwh:
    effective_threshold += 1

    new_peak_intervals = forecasted_load[forecasted_load > effective_threshold]

    if new_peak_intervals.empty:
      effective_threshold = forecasted_load.max() # This is the absolute LIMIT, is just a failsafe
      break

    # Calculate the power needed for the new threshold, again capped by max_power_kw
    new_power_needed_in_peaks = (new_peak_intervals - effective_threshold).clip(upper=max_power_kw)

    # Recalculate energy needed with the new threshold and capped power
    energy_needed_kwh = new_power_needed_in_peaks.sum() * interval_hours


  # print(f"Effective threshold adjusted to {effective_threshold:.2f} kW (requires {energy_needed_kwh:.2f} kWh).")
  return effective_threshold

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **3.3 Setting up the Function to reduce daily peak demand including Charging and Discharging of the battery system**

# %%
from typing_extensions import final
import numpy as np
import pandas as pd
import math

# The Final, Corrected, and most advanced simulation function
def simulate_daily_peak_reduction(
    forecasted_load,
    actual_load,
    actual_df,
    battery_capacity,
    max_power,
    initial_soc,
    shaving_percentage,
    target_date,
    tactical_scaler,
    short_term_predictor = None,
    safety_margin= 0.0,
    replan_buffer = 0.20,
    efficiency=0.90
):
    """
    Simulates peak shaving using a hybrid strategy:
    1. Proactively plans a threshold based on the full-day forecast.
    2. Reactively executes dispatch based on the actual load.
    """

    print("--- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---")

    # --- 1. STRATEGIC PLANNING PHASE (Done once at the start) ---
    plannable_energy = initial_soc * (1 - safety_margin)
    initial_threshold = forecasted_load.max() * (1 - shaving_percentage)

    # The 'Captain's Plan': Calculate the single best threshold for the day based on the forecast
    planned_threshold = calculate_effective_threshold( # Using the function from before
        forecasted_load, initial_threshold, plannable_energy
    )
    print(f"Strategic threshold for the day set to: {planned_threshold:.2f} kW")

    planned_dispatch = (forecasted_load.clip(lower = planned_threshold) - planned_threshold).clip(upper = max_power)
    planned_soc_trajectory = pd.Series(initial_soc - planned_dispatch.cumsum() * (1/60), index = forecasted_load.index)

    # Also based on the forecast, identify the best hours to recharge
    energy_used_in_plan = (forecasted_load[forecasted_load > planned_threshold] - planned_threshold).sum() * (1 / 60)
    energy_needed_from_grid = energy_used_in_plan / efficiency
    num_charge_intervals = int(np.ceil((energy_needed_from_grid / max_power) / (1/60)))
    charge_indices = np.argsort(forecasted_load.values)[:num_charge_intervals]

    # --- 2. TACTICAL EXECUTION PHASE (Loop through the day) ---
    num_intervals = len(forecasted_load)
    print(num_intervals)
    interval_hours = 1/60

    battery_dispatch_kw = np.zeros(num_intervals)
    soc_kwh = np.zeros(num_intervals + 1)
    soc_kwh[0] = initial_soc
    energy_discharged_so_far = 0.0
    threshold_over_time = np.full(num_intervals, planned_threshold)
    feature_order = tactical_scaler.get_feature_names_out()
    n_features = len(feature_order)

    final_threshold = planned_threshold

    has_replanned1 = False
    has_replaned2 = False
    has_replanned3 = False
    high_happen = False
    adjust_factor = 0.0
    recent_errors = []
    short_term_predictions = []
    feature_names_index = df.columns


    # Defining a scaling factor (tuning parameter)

    for i in range(num_intervals):
        current_soc = soc_kwh[i]
        current_hour = actual_load.index[i].hour
        current_minute = actual_load.index[i].minute
        dispatch_kw = 0
        lookback_window_size = 30

        if short_term_predictor and i >= lookback_window_size and (current_hour > 7 and current_hour < 18):
          # 1. Get the lookback data (past 60 minutes of the actual load)
          rows = actual_df.iloc[i - lookback_window_size : i]
          lookback_tactical_data = rows[feature_order]
          lookback_tactical_scaled = tactical_scaler.transform(lookback_tactical_data)
          input_for_tactical_model = lookback_tactical_scaled.reshape(1, lookback_window_size, n_features)

          # 2. Predict the load for CURRENT interval 'i'
          short_term_prediction_kw = short_term_predictor(input_for_tactical_model)
          # print(short_term_prediction_kw)
          short_term_prediction_kw = short_term_prediction_kw.numpy()
          dummy_row = np.zeros((5, n_features))
          target_column_name = 'Pt(kW)'
          target_index = actual_df.columns.get_loc(target_column_name)
          dummy_row[:, target_index] = short_term_prediction_kw
          inversed_row = tactical_scaler.inverse_transform(dummy_row)
          short_term_prediction_kw = inversed_row[:, target_index]
          prediction_for_this_step = np.mean(short_term_prediction_kw)
          # print(prediction_for_this_step)
          # print(short_forecast_kw)

          expected_upcoming_error = np.mean(prediction_for_this_step) - np.mean(forecasted_load.iloc[i : i + 5])
          final_threshold = planned_threshold + expected_upcoming_error

          # if current_hour == 9 and current_minute == 0 and abs(expected_upcoming_error) > 20:
          #   print(np.mean(prediction_for_this_step))
          #   final_threshold = planned_threshold + expected_upcoming_error
          #   print(planned_threshold, expected_upcoming_error)

        #   # if current_hour == 9 and current_minute == 45 and abs(expected_upcoming_error) > 20:
        #   #   final_threshold = planned_threshold + expected_upcoming_error

          # if current_hour > 7 and current_hour < 16:
          #   energy_required = (prediction_for_this_step - final_threshold) * (17 - current_hour)

          #   while (current_soc > energy_required):
          #     final_threshold -= 1
          #     energy_required = (prediction_for_this_step - final_threshold) * (17 - current_hour)

          if current_hour > 7 and current_hour < 17:

            energy_required = (prediction_for_this_step - final_threshold) * (17 - current_hour)

            while (current_soc < energy_required):
              final_threshold += 1
              energy_required = (prediction_for_this_step - final_threshold) * (17 - current_hour)

          # final_threshold *= 0.98

          # 3. Adjust Threshold
          # if (current_hour > 8):
          #   short_term_predictions.append(prediction_for_this_step)

          # if current_hour == 9 and current_minute == 0 and abs(expected_upcoming_error) > 20:
          #   print(expected_upcoming_error)
          #   final_threshold = planned_threshold + expected_upcoming_error
          # #   print(final_threshold)

          # # if current_hour == 10 and current_minute == 0 and current_soc > 110:
          # #   final_threshold -= 30

          # if current_hour == 9 and current_minute == 5:
          #   # average_peak = (max(short_term_predictions) + min(short_term_predictions)) / 2
          #   # average_peak = np.mean(prediction_for_this_step)
          #   print(short_term_predictions)
          #   average_peak = max(short_term_predictions)
          #   energy_required = (average_peak - final_threshold) * 6
          #   while current_soc > energy_required:
          #     final_threshold -= 1
          #     energy_required = (average_peak - final_threshold) * 6

          # if current_hour == 9 and current_minute == 10:
          #   # average_peak = np.mean(prediction_for_this_step)
          #   average_peak = max(short_term_predictions)
          #   # average_peak = (max(short_term_predictions) + min(short_term_predictions)) / 2
          #   print(f"AVG PEAK 1 : {average_peak}")
          #   # energy_required = (average_peak - final_threshold) * 20 * 1.2
          #   energy_required = (average_peak - final_threshold) * 6 * 1.2
          #   print(energy_required)
          #   while current_soc < energy_required:
          #     final_threshold += 1
          #     print(final_threshold)
          #     energy_required = (average_peak - final_threshold) * 6 * 1.2
          #     print(energy_required)

          # if current_hour == 11 and current_minute == 30:
          #   average_peak = (max(short_term_predictions) + min(short_term_predictions)) / 2
          #   print(f"AVG PEAK 2 : {average_peak}")
          #   # energy_required = (average_peak - final_threshold) * 20 * 1.2
          #   energy_required = (average_peak - final_threshold) * 4
          #   while current_soc < energy_required:
          #     final_threshold += 1
          #     energy_required = (average_peak - final_threshold) * 4

          # if current_hour == 11 and current_minute == 45:
          #   average_peak = (max(short_term_predictions) + min(short_term_predictions)) / 2
          #   print(f"AVG PEAK 2 : {average_peak}")
          #   energy_required = (average_peak - final_threshold) * 4
          #   while current_soc < energy_required:
          #     final_threshold += 1
          #     energy_required = (average_peak - final_threshold) * 4


          # if current_hour == 10 and current_minute == 0 and abs(expected_upcoming_error) > 20:
          #   final_threshold = planned_threshold + expected_upcoming_error
          #   print(final_threshold)

          # if current_hour == 13 and current_minute == 0 and abs(expected_upcoming_error) > 20:
          #   final_threshold = planned_threshold + expected_upcoming_error

          # if current_hour == 12 and current_minute == 0 and current_soc > 80:
          #   final_threshold = final_threshold - 30

          # if current_hour == 12 and current_minute == 0 and current_soc < 80:
          #   final_threshold = final_threshold + 30

          # if current_hour == 12 and current_minute == 0 and current_soc > 100:
          #   final_threshold = final_threshold - 30

        #   expected_upcoming_error = prediction_for_this_step - forecasted_load.iloc[i]
        #   # print(expected_upcoming_error)
        #   if (abs(expected_upcoming_error) < 50):
        #     alpha = 0.5
        #   elif (abs(expected_upcoming_error) < 100):
        #     alpha = 0.8
        #   else:
        #     alpha = 1.0

        #   final_threshold = planned_threshold + expected_upcoming_error * alpha
        # else:
        #   prediction_for_this_step = 0


          # short_term_prediction_kw = tactical_scaler.inverse_transform(short_term_prediction_kw)
          # short_term_prediction_kw = short_term_prediction_kw.flatten()

          # print(short_term_prediction_kw)

        threshold_over_time[i] = final_threshold

        # --- The 'Helmsman's' Logic ---
        # Priority 1: Is this a designated charging slot?
        if i in charge_indices:
            energy_room = battery_capacity - current_soc
            power_limit_by_room = energy_room / interval_hours
            power_to_charge = min(max_power, power_limit_by_room)
            dispatch_kw = -power_to_charge

        # Priority 2: If not charging, should we discharge?
        # The decision is now based on the ACTUAL load crossing the smart threshold
        elif actual_load.iloc[i] > final_threshold and current_soc > 0:
            # print(final_threshold)
            excess_power = actual_load.iloc[i] - final_threshold
            # print(f"Actual Load : {actual_load.iloc[i]}, Excess Power : {excess_power}, Final Threshold {final_threshold}, Planned Threshold {planned_threshold}, Forecast Error {expected_upcoming_error}")
            power_to_discharge = min(excess_power, max_power)
            power_limit_by_energy = current_soc / interval_hours
            dispatch_kw = min(power_to_discharge, power_limit_by_energy)

        # Update state based on the final action
        battery_dispatch_kw[i] = dispatch_kw
        energy_change = -dispatch_kw * interval_hours

        if dispatch_kw < 0: # Charging efficiency loss
            energy_change *= efficiency
        soc_kwh[i+1] = np.clip(soc_kwh[i] + energy_change, 0, battery_capacity)

        if dispatch_kw > 0:
          energy_discharged_so_far += dispatch_kw * interval_hours

    # --- 3. Final Results ---

    results = {
        "final_shaved_load": pd.Series(actual_load.values - battery_dispatch_kw, index=actual_load.index),
        "battery_soc_kwh": pd.Series(soc_kwh, index=pd.date_range(start=actual_load.index[0], periods=num_intervals + 1, freq='1min')),
        "final_threshold": final_threshold,
        "threshold_over_time": pd.Series(threshold_over_time, index = actual_load.index),
        # "short_term_forecast": pd.Series(short_term_predictions, index = actual_load.index),
        "Forecast_kW" : forecasted_load
    }
    return results

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **3.4 Testing the peak reduction logic with exact day, simulating the day, setting up the specifications of the battery system**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
import os

# For this script, we assume you have ALREADY loaded the following:
# model: Your trained Direct Multi-Step Keras model
# scaler: Your fitted MinMaxScaler object
# df_final: Your complete, cleaned, and feature-rich historical DataFrame
# create_multi_step_sequences: The helper function for data prep (if needed for comparison)

# --- ====================================================================== ---
# === Part 1: SETUP & CONFIGURATION ===
# --- ====================================================================== ---

# ==> YOUR ACTION: Choose the specific day you want to run the simulation for
TARGET_DATE = '2024-07-19'

# --- Model & Data Parameters (MUST match your training setup) ---
n_lookback = 96  # History window (24 hors)
n_forecast = 96  # Forecast window (24 hours)
feature_order = strategic_scaler.get_feature_names_out() # Get feature order from the scaler
n_features = len(feature_order)
data_column = feature_order[0] # Your target variable, e.g., 'Pt(kW)'

# --- Battery & Strategy Parameters ---
BATTERY_CAPACITY_KWH = 120.0
BATTERY_MAX_POWER_KW = 100.0
INITIAL_SOC_KWH = BATTERY_CAPACITY_KWH
BATTERY_EFFICIENCY = 0.90
SHAVING_PERCENTAGE = 0.15 # Target to shave 10% off the forecasted peak
# SAFETY_MARGIN = 0.0

print(f"--- Preparing Simulation for Target Date: {TARGET_DATE} ---")


# --- ====================================================================== ---
# === Part 2: GENERATE THE DAY-AHEAD FORECAST ===
# --- ====================================================================== ---
print("\nStep 1: Generating the 24-hour forecast...")

# a) Get the 24-hour lookback window from the day BEFORE the target date
lookback_start_date = pd.to_datetime(TARGET_DATE) - pd.Timedelta(days=1)
lookback_start_str = lookback_start_date.strftime('%Y-%m-%d')

# For 192 lookback, which means looking back 2 days
# lookback_end_date = pd.to_datetime(TARGET_DATE) - pd.Timedelta(minutes = 15)
# lookback_end_str = lookback_end_date.strftime('%Y-%m-%d')

lookback_data_raw = df_final1.loc[lookback_start_str, feature_order]

# b) Scale the lookback data
lookback_scaled = strategic_scaler.transform(lookback_data_raw)

# c) Reshape for the model input: [1 sample, 96 timesteps, N features]
input_for_model = lookback_scaled.reshape((1, n_lookback, n_features))

# d) Make the prediction (output is scaled, shape is (1, 96))
prediction_scaled = strategic_model.predict(input_for_model)

# e) Inverse scale the prediction to get real kW values
# This helper function encapsulates the "dummy array" trick
def inverse_scale_forecast(scaled_prediction, scaler_obj, n_features, n_forecast_steps):
    dummy_array = np.zeros((1 * n_forecast_steps, n_features))
    dummy_array[:, 0] = scaled_prediction.flatten()
    inversed_array = scaler_obj.inverse_transform(dummy_array)
    return inversed_array[:, 0]

forecast_kw = inverse_scale_forecast(prediction_scaled, strategic_scaler, n_features, n_forecast)

# f) Create a clean DataFrame for the forecast
forecast_index = pd.date_range(start=TARGET_DATE, periods=96, freq='15min')
forecast_df = pd.DataFrame({'Forecast_kW': forecast_kw}, index=forecast_index)
print("✅ Forecast generated successfully.")

# --- ====================================================================== ---
# === Part 3: RUN THE PEAK SHAVING SIMULATION ===
# --- ====================================================================== ---
print("\nStep 2: Running the peak shaving simulation using the forecast...")

# Get the ACTUAL load for the target day to measure the real-world outcome
# actual_load_for_day = df_final.loc[TARGET_DATE, data_column]
# print(actual_load_for_day)


forecasted_load = forecast_df['Forecast_kW']
# 1. Create a full 1440-minute index for the day
full_day_index = pd.date_range(start=forecasted_load.index.min().date(), periods=1440, freq='1min')

# 2. Reindex your data to the full day and then interpolate
forecasted_load_full = forecasted_load.reindex(full_day_index).interpolate(method='time')

# forecasted_load = forecasted_load.resample('1min').interpolate(method= 'time')

# print(forecasted_load.max())


actual_load = pd.read_csv('/content/combine_1.csv')
actual_load['Time'] = pd.to_datetime(actual_load['Time'])
actual_load = actual_load.set_index('Time')
actual_load_for_day = actual_load.loc[TARGET_DATE]
# actual_load_for_day = actual_load_for_day.resample('1min').mean()

actual_df_for_day = df_final.loc[TARGET_DATE]

# Get the final, smart threshold from the rationing logic

# Run the main simulation to get the battery dispatch plan
sim_results = simulate_daily_peak_reduction(
    forecasted_load=forecasted_load_full,
    actual_load = actual_load_for_day['Pt(kW)'],
    actual_df = actual_df_for_day,
    battery_capacity =BATTERY_CAPACITY_KWH,
    max_power = BATTERY_MAX_POWER_KW,
    initial_soc = INITIAL_SOC_KWH,
    tactical_scaler = tactical_scaler,
    short_term_predictor = tactical_model,
    efficiency=BATTERY_EFFICIENCY,
    target_date = TARGET_DATE,
    shaving_percentage = SHAVING_PERCENTAGE
)
print("✅ Simulation complete.")

# --- ====================================================================== ---
# === Part 4: ANALYZE AND VISUALIZE THE FINAL RESULTS ===
# --- ====================================================================== ---
print("\nStep 3: Analyzing and plotting the final outcome...")

# Storing the key-results into the list
original_peak = actual_load_for_day['Pt(kW)'].max()
new_peak = sim_results['final_shaved_load'].max()
peak_reduction = original_peak - new_peak

# --- CORRECTED 30-MINUTE PEAK CALCULATION ---
# Calculate the 30-minute rolling average for every minute of the day
original_30_rolling = actual_load_for_day['Pt(kW)'].rolling(window=30, min_periods=30).mean()
new_30_rolling = sim_results['final_shaved_load'].rolling(window=30, min_periods=30).mean()

# The true 30-minute peak is the maximum value from these rolling averages
original_30_peak = original_30_rolling.max()
new_30_peak = new_30_rolling.max()
peak_reduction_30 = original_30_peak - new_30_peak
print(peak_reduction_30)


print("\n--- Final Simulation Results ---")
print(f"Original Actual Peak: {original_peak:.2f} kW")
print(f"New Simulated Peak:   {new_peak:.2f} kW")
print(f"Peak Demand Reduced:  {peak_reduction:.2f} kW ({ (peak_reduction/original_peak)*100 :.2f}%)")

# --- Final Visualization ---
fig, ax1 = plt.subplots(figsize=(15, 8))
ax1.plot(actual_load_for_day['Pt(kW)'], label='Original Actual Load', color='blue', linewidth=2.5)
ax1.plot(forecast_df['Forecast_kW'], label='AI Forecast', color='orange', linestyle=':', alpha=0.9)
ax1.plot(sim_results['final_shaved_load'], label='Load After Peak Shaving', color='green', linewidth=2)
# ax1.plot(sim_results['short_term_forecast'], label='Short Term Forecast', color='black', linewidth=1.5)
# ax1.axhline(y=sim_results['final_threshold'], color='red', linestyle='--', label=f"Final Target Threshold {sim_results['final_threshold']} kW)")
ax1.plot(
    sim_results['threshold_over_time'],
    label='Adaptive Target Threshold',
    color='red',
    linestyle='--'
)
ax1.set_xlabel('Time')
ax1.set_ylabel('Power (kW)', color='blue')
ax1.legend(loc='upper left')
ax1.grid(True)
ax2 = ax1.twinx()
ax2.plot(sim_results['battery_soc_kwh'], label='Battery State of Charge (SoC)', color='purple', linestyle=':', marker='.')
ax2.set_ylabel('Battery Energy (kWh)', color='purple')
ax2.legend(loc='upper right')
ax2.set_ylim(0, BATTERY_CAPACITY_KWH * 1.1)
plt.title(f'Complete Peak Shaving Simulation for {TARGET_DATE}')
fig.tight_layout()
plt.show()
# Out:
# --- Preparing Simulation for Target Date: 2024-07-19 ---
#
# Step 1: Generating the 24-hour forecast...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Forecast generated successfully.
#
# Step 2: Running the peak shaving simulation using the forecast...
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1019.12 kW
# 1440
# ✅ Simulation complete.
#
# Step 3: Analyzing and plotting the final outcome...
# 0.0
#
# --- Final Simulation Results ---
# Original Actual Peak: 1031.75 kW
# New Simulated Peak:   1031.75 kW
# Peak Demand Reduced:  0.00 kW (0.00%)

# %% [markdown]
# --------------------------------------------------------------------------------
# ## **3.5 Defining the parameters / specifications of the battery system / Running the functions**

# %% [markdown]
# Running the functions and Evaluating the results

# %%
simulation_start_date = '2024-04-30'
simulation_end_date = '2025-02-22'
simulation_duration_days = (pd.to_datetime(simulation_end_date) - pd.to_datetime(simulation_start_date)).days

all_results = []
print(f"Starting Rolling Forecast Simulation starting from {simulation_start_date}")
actual_load = pd.read_csv('/content/combine_1.csv')
actual_load['Time'] = pd.to_datetime(actual_load['Time'])
actual_load = actual_load.set_index('Time')
# actual_load_for_day = actual_load.resample('5min').mean()

for i in range(simulation_duration_days):
  # Determine the current day that we are forecasting now
  target_date = pd.to_datetime(simulation_start_date) + pd.Timedelta(days = i)
  print(target_date)
  target_date_str = target_date.strftime('%Y-%m-%d')
  print(target_date_str)

  # Finding the historical data that we need to perform the forecast
  lookback_date = target_date - pd.Timedelta(days = 1)
  lookback_date_str = lookback_date.strftime('%Y-%m-%d')

  # For looking back 192 samples --> lookback for 2 days
  # lookback_end_date = target_date - pd.Timedelta(minutes = 15)
  # lookback_end_str = lookback_end_date.strftime('%Y-%m-%d')

  try:
    lookback_data_raw = df_final1.loc[lookback_date_str, feature_order]

    # Getting the weather forecast and actual load for the target day
    forecast_inputs = df_final1.loc[target_date_str]

    # actual_load_for_day = forecast_inputs[data_column]
    weather_forecast_for_day = forecast_inputs.drop(columns = [data_column])

    # Generating the AI forecast
    lookback_scaled = strategic_scaler.transform(lookback_data_raw)
    input_for_model = lookback_scaled.reshape(1, n_lookback, n_features)

    # Making the prediction
    prediction_scaled = strategic_model.predict(input_for_model, verbose = 1)

    # --- 1. Create the initial 15-minute forecast DataFrame (your code is correct here) ---
    forecast_kw = inverse_scale_forecast(prediction_scaled, strategic_scaler, n_features, n_forecast)
    forecast_index = pd.date_range(start=target_date_str, periods=96, freq='15min')
    forecast_df = pd.DataFrame({'Forecast_kW': forecast_kw}, index=forecast_index)


    # --- 2. Correctly upsample to a 1-minute forecast for the simulation ---
    # Create a complete 1-minute index for the entire day
    full_day_index = pd.date_range(start=forecast_df.index.min().date(), periods=1440, freq='1min')

    # Reindex the 15-minute forecast to the 1-minute index, then interpolate the gaps.
    # We select the 'Forecast_kW' column at the end to get a clean pandas Series.
    forecasted_load = forecast_df.reindex(full_day_index).interpolate(method='time')['Forecast_kW']

    actual_load_for_day2 = actual_load.loc[target_date_str]
    # actual_load_for_day2 = actual_load_for_day.loc[forecasted_load.index]


    # Running the peak reduction simulation
    sim_results = simulate_daily_peak_reduction(
    forecasted_load=forecasted_load,
    actual_load = actual_load_for_day2['Pt(kW)'],
    actual_df = df_final.loc[target_date_str],
    short_term_predictor = tactical_model,
    tactical_scaler = tactical_scaler,
    battery_capacity =BATTERY_CAPACITY_KWH,
    max_power = BATTERY_MAX_POWER_KW,
    initial_soc = INITIAL_SOC_KWH,
    efficiency=BATTERY_EFFICIENCY,
    target_date = target_date_str,
    shaving_percentage = SHAVING_PERCENTAGE
)

    # Storing the key-results into the list
    original_peak = actual_load_for_day2['Pt(kW)'].max()
    new_peak = sim_results['final_shaved_load'].max()

    # --- CORRECTED 30-MINUTE PEAK CALCULATION ---
    # Calculate the 30-minute rolling average for every minute of the day
    original_30_rolling = actual_load_for_day2['Pt(kW)'].rolling(window=30, min_periods=30).mean()
    new_30_rolling = sim_results['final_shaved_load'].rolling(window=30, min_periods=30).mean()

    # The true 30-minute peak is the maximum value from these rolling averages
    original_30_peak = original_30_rolling.max()
    new_30_peak = new_30_rolling.max()
    peak_reduction_30 = original_30_peak - new_30_peak

    # Your summary dictionary remains the same
    daily_summary = {
        'Date': target_date,
        'Original_peak': original_30_peak,
        'Reduced_peak': new_30_peak,
        'Reduction_kW': peak_reduction_30,
    }


    all_results.append(daily_summary)

    # fig, ax1 = plt.subplots(figsize=(20, 8))
    # ax1.plot(actual_load_for_day2['Pt(kW)'], label='Original Actual Load', color='blue', linewidth=2.5)
    # ax1.plot(forecast_df['Forecast_kW'], label='AI Forecast', color='orange', linestyle=':', alpha=0.9)
    # ax1.plot(sim_results['final_shaved_load'], label='Load After Peak Shaving', color='green', linewidth=2)
    # # ax1.axhline(y=sim_results['final_threshold'], color='red', linestyle='--', label=f"Final Target Threshold {sim_results['final_threshold']} kW)")
    # ax1.plot(
    # sim_results['threshold_over_time'],
    # label='Adaptive Target Threshold',
    # color='red',
    # linestyle='--'
    # )
    # ax1.axhline(y=ideal_threshold, color='cyan', linestyle='-.', label=f'Ideal Threshold ({ideal_threshold:.0f} kW)')
    # ax1.set_xlabel('Time')
    # ax1.set_ylabel('Power (kW)', color='blue')
    # ax1.legend(loc='upper left')
    # ax1.grid(True)
    # ax2 = ax1.twinx()
    # ax2.plot(sim_results['battery_soc_kwh'], label='Battery State of Charge (SoC)', color='purple', linestyle=':', marker='.')
    # ax2.set_ylabel('Battery Energy (kWh)', color='purple')
    # ax2.legend(loc='upper right')
    # ax2.set_ylim(0, BATTERY_CAPACITY_KWH * 1.1)
    # plt.title(f'Complete Peak Shaving Simulation for {target_date_str}')
    # fig.tight_layout()
    # # filename = os.path.join(output_dir, f"{target_date_str}")
    # plt.savefig(f"/content/drive/MyDrive/FYP Project - Designing a controller to reduce peak demand/simulation results 20 07 2025/{target_date_str}.png")
    # plt.show()

  except Exception as e:
    print(f"Skipping {target_date_str}")

# Analysing the final results
results_summary_df = pd.DataFrame(all_results)
results_summary_df['Date'] = pd.to_datetime(results_summary_df['Date'])
results_summary_df = results_summary_df.set_index('Date')

print('\n --- Simulation Summary Over All Days ---')
print(results_summary_df)

  # total_reduction = results_summary_df['Reduction_kW'].sum()
  # print(f"Total Peak Reduction over the period is {total_reduction:.2f} kW")
# Out:
# Starting Rolling Forecast Simulation starting from 2024-04-30
# 2024-04-30 00:00:00
# 2024-04-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1124.41 kW
# 1440
# 2024-05-01 00:00:00
# 2024-05-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1074.81 kW
# 1440
# 2024-05-02 00:00:00
# 2024-05-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1041.05 kW
# 1440
# 2024-05-03 00:00:00
# 2024-05-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1043.20 kW
# 1440
# 2024-05-04 00:00:00
# 2024-05-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 501.86 kW
# 1440
# 2024-05-05 00:00:00
# 2024-05-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 253.92 kW
# 1440
# 2024-05-06 00:00:00
# 2024-05-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1105.90 kW
# 1440
# 2024-05-07 00:00:00
# 2024-05-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1097.33 kW
# 1440
# 2024-05-08 00:00:00
# 2024-05-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1016.50 kW
# 1440
# 2024-05-09 00:00:00
# 2024-05-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1049.62 kW
# 1440
# 2024-05-10 00:00:00
# 2024-05-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1044.98 kW
# 1440
# 2024-05-11 00:00:00
# 2024-05-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 641.21 kW
# 1440
# 2024-05-12 00:00:00
# 2024-05-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 348.69 kW
# 1440
# 2024-05-13 00:00:00
# 2024-05-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1082.42 kW
# 1440
# 2024-05-14 00:00:00
# 2024-05-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1099.92 kW
# 1440
# 2024-05-15 00:00:00
# 2024-05-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 965.09 kW
# 1440
# 2024-05-16 00:00:00
# 2024-05-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1033.01 kW
# 1440
# 2024-05-17 00:00:00
# 2024-05-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1000.07 kW
# 1440
# 2024-05-18 00:00:00
# 2024-05-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 541.11 kW
# 1440
# 2024-05-19 00:00:00
# 2024-05-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 381.84 kW
# 1440
# 2024-05-20 00:00:00
# 2024-05-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1074.06 kW
# 1440
# 2024-05-21 00:00:00
# 2024-05-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1124.27 kW
# 1440
# 2024-05-22 00:00:00
# 2024-05-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1011.59 kW
# 1440
# 2024-05-23 00:00:00
# 2024-05-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 955.49 kW
# 1440
# 2024-05-24 00:00:00
# 2024-05-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1080.33 kW
# 1440
# 2024-05-25 00:00:00
# 2024-05-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 562.96 kW
# 1440
# 2024-05-26 00:00:00
# 2024-05-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 282.12 kW
# 1440
# 2024-05-27 00:00:00
# 2024-05-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1099.30 kW
# 1440
# 2024-05-28 00:00:00
# 2024-05-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1126.35 kW
# 1440
# 2024-05-29 00:00:00
# 2024-05-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 937.35 kW
# 1440
# 2024-05-30 00:00:00
# 2024-05-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1031.54 kW
# 1440
# 2024-05-31 00:00:00
# 2024-05-31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 944.55 kW
# 1440
# 2024-06-01 00:00:00
# 2024-06-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 462.48 kW
# 1440
# 2024-06-02 00:00:00
# 2024-06-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 247.41 kW
# 1440
# 2024-06-03 00:00:00
# 2024-06-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1017.23 kW
# 1440
# 2024-06-04 00:00:00
# 2024-06-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 951.63 kW
# 1440
# 2024-06-05 00:00:00
# 2024-06-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 892.94 kW
# 1440
# 2024-06-06 00:00:00
# 2024-06-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 930.51 kW
# 1440
# 2024-06-07 00:00:00
# 2024-06-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 920.09 kW
# 1440
# 2024-06-08 00:00:00
# 2024-06-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 331.78 kW
# 1440
# 2024-06-09 00:00:00
# 2024-06-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 299.59 kW
# 1440
# 2024-06-10 00:00:00
# 2024-06-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1031.45 kW
# 1440
# 2024-06-11 00:00:00
# 2024-06-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 987.25 kW
# 1440
# 2024-06-12 00:00:00
# 2024-06-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 933.57 kW
# 1440
# 2024-06-13 00:00:00
# 2024-06-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 958.64 kW
# 1440
# 2024-06-14 00:00:00
# 2024-06-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 966.16 kW
# 1440
# 2024-06-15 00:00:00
# 2024-06-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 409.71 kW
# 1440
# 2024-06-16 00:00:00
# 2024-06-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 277.59 kW
# 1440
# 2024-06-17 00:00:00
# 2024-06-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1007.37 kW
# 1440
# 2024-06-18 00:00:00
# 2024-06-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 899.57 kW
# 1440
# 2024-06-19 00:00:00
# 2024-06-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 955.19 kW
# 1440
# 2024-06-20 00:00:00
# 2024-06-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 975.91 kW
# 1440
# 2024-06-21 00:00:00
# 2024-06-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 994.97 kW
# 1440
# 2024-06-22 00:00:00
# 2024-06-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 358.57 kW
# 1440
# 2024-06-23 00:00:00
# 2024-06-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 263.53 kW
# 1440
# 2024-06-24 00:00:00
# 2024-06-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1065.55 kW
# 1440
# 2024-06-25 00:00:00
# 2024-06-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1076.55 kW
# 1440
# 2024-06-26 00:00:00
# 2024-06-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1055.33 kW
# 1440
# 2024-06-27 00:00:00
# 2024-06-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1023.19 kW
# 1440
# 2024-06-28 00:00:00
# 2024-06-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1027.48 kW
# 1440
# 2024-06-29 00:00:00
# 2024-06-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 345.24 kW
# 1440
# 2024-06-30 00:00:00
# 2024-06-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 332.00 kW
# 1440
# 2024-07-01 00:00:00
# 2024-07-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1040.04 kW
# 1440
# 2024-07-02 00:00:00
# 2024-07-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1095.22 kW
# 1440
# 2024-07-03 00:00:00
# 2024-07-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1048.07 kW
# 1440
# 2024-07-04 00:00:00
# 2024-07-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1047.62 kW
# 1440
# 2024-07-05 00:00:00
# 2024-07-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1013.87 kW
# 1440
# 2024-07-06 00:00:00
# 2024-07-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 531.49 kW
# 1440
# 2024-07-07 00:00:00
# 2024-07-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 293.57 kW
# 1440
# 2024-07-08 00:00:00
# 2024-07-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1056.46 kW
# 1440
# 2024-07-09 00:00:00
# 2024-07-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1000.38 kW
# 1440
# 2024-07-10 00:00:00
# 2024-07-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1001.00 kW
# 1440
# 2024-07-11 00:00:00
# 2024-07-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 946.83 kW
# 1440
# 2024-07-12 00:00:00
# 2024-07-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1006.68 kW
# 1440
# 2024-07-13 00:00:00
# 2024-07-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 365.86 kW
# 1440
# 2024-07-14 00:00:00
# 2024-07-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 272.92 kW
# 1440
# 2024-07-15 00:00:00
# 2024-07-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1052.48 kW
# 1440
# 2024-07-16 00:00:00
# 2024-07-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1073.30 kW
# 1440
# 2024-07-17 00:00:00
# 2024-07-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1026.64 kW
# 1440
# 2024-07-18 00:00:00
# 2024-07-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1045.37 kW
# 1440
# 2024-07-19 00:00:00
# 2024-07-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1019.12 kW
# 1440
# 2024-07-20 00:00:00
# 2024-07-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 405.68 kW
# 1440
# 2024-07-21 00:00:00
# 2024-07-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 298.42 kW
# 1440
# 2024-07-22 00:00:00
# 2024-07-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1060.20 kW
# 1440
# 2024-07-23 00:00:00
# 2024-07-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1081.46 kW
# 1440
# 2024-07-24 00:00:00
# 2024-07-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1054.05 kW
# 1440
# 2024-07-25 00:00:00
# 2024-07-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1049.88 kW
# 1440
# 2024-07-26 00:00:00
# 2024-07-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1028.13 kW
# 1440
# 2024-07-27 00:00:00
# 2024-07-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 541.96 kW
# 1440
# 2024-07-28 00:00:00
# 2024-07-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 261.96 kW
# 1440
# 2024-07-29 00:00:00
# 2024-07-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1088.81 kW
# 1440
# 2024-07-30 00:00:00
# 2024-07-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1086.64 kW
# 1440
# 2024-07-31 00:00:00
# 2024-07-31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1053.72 kW
# 1440
# 2024-08-01 00:00:00
# 2024-08-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1024.72 kW
# 1440
# 2024-08-02 00:00:00
# 2024-08-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1025.18 kW
# 1440
# 2024-08-03 00:00:00
# 2024-08-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 515.96 kW
# 1440
# 2024-08-04 00:00:00
# 2024-08-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 274.38 kW
# 1440
# 2024-08-05 00:00:00
# 2024-08-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1066.44 kW
# 1440
# 2024-08-06 00:00:00
# 2024-08-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1058.61 kW
# 1440
# 2024-08-07 00:00:00
# 2024-08-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 975.21 kW
# 1440
# 2024-08-08 00:00:00
# 2024-08-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1002.13 kW
# 1440
# 2024-08-09 00:00:00
# 2024-08-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 980.74 kW
# 1440
# 2024-08-10 00:00:00
# 2024-08-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 393.38 kW
# 1440
# 2024-08-11 00:00:00
# 2024-08-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 294.26 kW
# 1440
# 2024-08-12 00:00:00
# 2024-08-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1044.92 kW
# 1440
# 2024-08-13 00:00:00
# 2024-08-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1055.63 kW
# 1440
# 2024-08-14 00:00:00
# 2024-08-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1024.22 kW
# 1440
# 2024-08-15 00:00:00
# 2024-08-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1020.59 kW
# 1440
# 2024-08-16 00:00:00
# 2024-08-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1020.88 kW
# 1440
# 2024-08-17 00:00:00
# 2024-08-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 484.35 kW
# 1440
# 2024-08-18 00:00:00
# 2024-08-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 340.97 kW
# 1440
# 2024-08-19 00:00:00
# 2024-08-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1068.48 kW
# 1440
# 2024-08-20 00:00:00
# 2024-08-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1073.67 kW
# 1440
# 2024-08-21 00:00:00
# 2024-08-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 954.35 kW
# 1440
# 2024-08-22 00:00:00
# 2024-08-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1015.24 kW
# 1440
# 2024-08-23 00:00:00
# 2024-08-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 966.76 kW
# 1440
# 2024-08-24 00:00:00
# 2024-08-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 331.00 kW
# 1440
# 2024-08-25 00:00:00
# 2024-08-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 315.37 kW
# 1440
# 2024-08-26 00:00:00
# 2024-08-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1031.59 kW
# 1440
# 2024-08-27 00:00:00
# 2024-08-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1011.96 kW
# 1440
# 2024-08-28 00:00:00
# 2024-08-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 937.23 kW
# 1440
# 2024-08-29 00:00:00
# 2024-08-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 994.44 kW
# 1440
# 2024-08-30 00:00:00
# 2024-08-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 992.07 kW
# 1440
# 2024-08-31 00:00:00
# 2024-08-31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 498.80 kW
# 1440
# 2024-09-01 00:00:00
# 2024-09-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 233.90 kW
# 1440
# 2024-09-02 00:00:00
# 2024-09-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1084.16 kW
# 1440
# 2024-09-03 00:00:00
# 2024-09-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1076.33 kW
# 1440
# 2024-09-04 00:00:00
# 2024-09-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1003.95 kW
# 1440
# 2024-09-05 00:00:00
# 2024-09-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1036.38 kW
# 1440
# 2024-09-06 00:00:00
# 2024-09-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 999.74 kW
# 1440
# 2024-09-07 00:00:00
# 2024-09-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 518.26 kW
# 1440
# 2024-09-08 00:00:00
# 2024-09-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 219.96 kW
# 1440
# 2024-09-09 00:00:00
# 2024-09-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1069.65 kW
# 1440
# 2024-09-10 00:00:00
# 2024-09-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1054.59 kW
# 1440
# 2024-09-11 00:00:00
# 2024-09-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 927.78 kW
# 1440
# 2024-09-12 00:00:00
# 2024-09-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1014.13 kW
# 1440
# 2024-09-13 00:00:00
# 2024-09-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 945.52 kW
# 1440
# 2024-09-14 00:00:00
# 2024-09-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 323.88 kW
# 1440
# 2024-09-15 00:00:00
# 2024-09-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 316.39 kW
# 1440
# 2024-09-16 00:00:00
# 2024-09-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 994.66 kW
# 1440
# 2024-09-17 00:00:00
# 2024-09-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 871.94 kW
# 1440
# 2024-09-18 00:00:00
# 2024-09-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 855.72 kW
# 1440
# 2024-09-19 00:00:00
# 2024-09-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 924.10 kW
# 1440
# 2024-09-20 00:00:00
# 2024-09-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 885.85 kW
# 1440
# 2024-09-21 00:00:00
# 2024-09-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 481.09 kW
# 1440
# 2024-09-22 00:00:00
# 2024-09-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 152.97 kW
# 1440
# 2024-09-23 00:00:00
# 2024-09-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1034.89 kW
# 1440
# 2024-09-24 00:00:00
# 2024-09-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1095.21 kW
# 1440
# 2024-09-25 00:00:00
# 2024-09-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 979.21 kW
# 1440
# 2024-09-26 00:00:00
# 2024-09-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1002.23 kW
# 1440
# 2024-09-27 00:00:00
# 2024-09-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 938.89 kW
# 1440
# 2024-09-28 00:00:00
# 2024-09-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 550.95 kW
# 1440
# 2024-09-29 00:00:00
# 2024-09-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 307.21 kW
# 1440
# 2024-09-30 00:00:00
# 2024-09-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 966.43 kW
# 1440
# 2024-10-01 00:00:00
# 2024-10-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1047.91 kW
# 1440
# 2024-10-02 00:00:00
# 2024-10-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 961.64 kW
# 1440
# 2024-10-03 00:00:00
# 2024-10-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1002.55 kW
# 1440
# 2024-10-04 00:00:00
# 2024-10-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 933.58 kW
# 1440
# 2024-10-05 00:00:00
# 2024-10-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 301.97 kW
# 1440
# 2024-10-06 00:00:00
# 2024-10-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 404.17 kW
# 1440
# 2024-10-07 00:00:00
# 2024-10-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 882.04 kW
# 1440
# 2024-10-08 00:00:00
# 2024-10-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1045.42 kW
# 1440
# 2024-10-09 00:00:00
# 2024-10-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 940.96 kW
# 1440
# 2024-10-10 00:00:00
# 2024-10-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 932.65 kW
# 1440
# 2024-10-11 00:00:00
# 2024-10-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 929.76 kW
# 1440
# 2024-10-12 00:00:00
# 2024-10-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 334.27 kW
# 1440
# 2024-10-13 00:00:00
# 2024-10-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 241.16 kW
# 1440
# 2024-10-14 00:00:00
# 2024-10-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1014.63 kW
# 1440
# 2024-10-15 00:00:00
# 2024-10-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 958.61 kW
# 1440
# 2024-10-16 00:00:00
# 2024-10-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 874.98 kW
# 1440
# 2024-10-17 00:00:00
# 2024-10-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 946.96 kW
# 1440
# 2024-10-18 00:00:00
# 2024-10-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 910.56 kW
# 1440
# 2024-10-19 00:00:00
# 2024-10-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 498.67 kW
# 1440
# 2024-10-20 00:00:00
# 2024-10-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Initial threshold 158.74 kW is feasible with available energy 120.00 kWh.
# Strategic threshold for the day set to: 158.74 kW
# 1440
# 2024-10-21 00:00:00
# 2024-10-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1043.80 kW
# 1440
# 2024-10-22 00:00:00
# 2024-10-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1023.24 kW
# 1440
# 2024-10-23 00:00:00
# 2024-10-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 960.49 kW
# 1440
# 2024-10-24 00:00:00
# 2024-10-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 963.37 kW
# 1440
# 2024-10-25 00:00:00
# 2024-10-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 921.81 kW
# 1440
# 2024-10-26 00:00:00
# 2024-10-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 294.93 kW
# 1440
# 2024-10-27 00:00:00
# 2024-10-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 344.58 kW
# 1440
# 2024-10-28 00:00:00
# 2024-10-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 950.57 kW
# 1440
# 2024-10-29 00:00:00
# 2024-10-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1008.90 kW
# 1440
# 2024-10-30 00:00:00
# 2024-10-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 951.45 kW
# 1440
# 2024-10-31 00:00:00
# 2024-10-31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1002.81 kW
# 1440
# 2024-11-01 00:00:00
# 2024-11-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 926.30 kW
# 1440
# 2024-11-02 00:00:00
# 2024-11-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 574.96 kW
# 1440
# 2024-11-03 00:00:00
# 2024-11-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 318.33 kW
# 1440
# 2024-11-04 00:00:00
# 2024-11-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1040.91 kW
# 1440
# 2024-11-05 00:00:00
# 2024-11-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 926.07 kW
# 1440
# 2024-11-06 00:00:00
# 2024-11-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 939.41 kW
# 1440
# 2024-11-07 00:00:00
# 2024-11-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 957.52 kW
# 1440
# 2024-11-08 00:00:00
# 2024-11-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 957.14 kW
# 1440
# 2024-11-09 00:00:00
# 2024-11-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 393.54 kW
# 1440
# 2024-11-10 00:00:00
# 2024-11-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 338.67 kW
# 1440
# 2024-11-11 00:00:00
# 2024-11-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 984.60 kW
# 1440
# 2024-11-12 00:00:00
# 2024-11-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1003.70 kW
# 1440
# 2024-11-13 00:00:00
# 2024-11-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 935.98 kW
# 1440
# 2024-11-14 00:00:00
# 2024-11-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 940.09 kW
# 1440
# 2024-11-15 00:00:00
# 2024-11-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 916.20 kW
# 1440
# 2024-11-16 00:00:00
# 2024-11-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 347.08 kW
# 1440
# 2024-11-17 00:00:00
# 2024-11-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 225.37 kW
# 1440
# 2024-11-18 00:00:00
# 2024-11-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 990.32 kW
# 1440
# 2024-11-19 00:00:00
# 2024-11-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1024.64 kW
# 1440
# 2024-11-20 00:00:00
# 2024-11-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 922.32 kW
# 1440
# 2024-11-21 00:00:00
# 2024-11-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 953.36 kW
# 1440
# 2024-11-22 00:00:00
# 2024-11-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 940.53 kW
# 1440
# 2024-11-23 00:00:00
# 2024-11-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 334.40 kW
# 1440
# 2024-11-24 00:00:00
# 2024-11-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 220.63 kW
# 1440
# 2024-11-25 00:00:00
# 2024-11-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1037.37 kW
# 1440
# 2024-11-26 00:00:00
# 2024-11-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1031.68 kW
# 1440
# 2024-11-27 00:00:00
# 2024-11-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 935.02 kW
# 1440
# 2024-11-28 00:00:00
# 2024-11-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 931.79 kW
# 1440
# 2024-11-29 00:00:00
# 2024-11-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 906.25 kW
# 1440
# 2024-11-30 00:00:00
# 2024-11-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 318.48 kW
# 1440
# 2024-12-01 00:00:00
# 2024-12-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Initial threshold 192.44 kW is feasible with available energy 120.00 kWh.
# Strategic threshold for the day set to: 192.44 kW
# 1440
# 2024-12-02 00:00:00
# 2024-12-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 922.43 kW
# 1440
# 2024-12-03 00:00:00
# 2024-12-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 978.62 kW
# 1440
# 2024-12-04 00:00:00
# 2024-12-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 934.42 kW
# 1440
# 2024-12-05 00:00:00
# 2024-12-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 933.31 kW
# 1440
# 2024-12-06 00:00:00
# 2024-12-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 953.70 kW
# 1440
# 2024-12-07 00:00:00
# 2024-12-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 599.75 kW
# 1440
# 2024-12-08 00:00:00
# 2024-12-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 304.80 kW
# 1440
# 2024-12-09 00:00:00
# 2024-12-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1051.55 kW
# 1440
# 2024-12-10 00:00:00
# 2024-12-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 890.14 kW
# 1440
# 2024-12-11 00:00:00
# 2024-12-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 874.65 kW
# 1440
# Skipping 2024-12-11
# 2024-12-12 00:00:00
# 2024-12-12
# Skipping 2024-12-12
# 2024-12-13 00:00:00
# 2024-12-13
# Skipping 2024-12-13
# 2024-12-14 00:00:00
# 2024-12-14
# Skipping 2024-12-14
# 2024-12-15 00:00:00
# 2024-12-15
# Skipping 2024-12-15
# 2024-12-16 00:00:00
# 2024-12-16
# Skipping 2024-12-16
# 2024-12-17 00:00:00
# 2024-12-17
# Skipping 2024-12-17
# 2024-12-18 00:00:00
# 2024-12-18
# Skipping 2024-12-18
# 2024-12-19 00:00:00
# 2024-12-19
# Skipping 2024-12-19
# 2024-12-20 00:00:00
# 2024-12-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 924.94 kW
# 1440
# 2024-12-21 00:00:00
# 2024-12-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 347.88 kW
# 1440
# 2024-12-22 00:00:00
# 2024-12-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 369.25 kW
# 1440
# 2024-12-23 00:00:00
# 2024-12-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 886.20 kW
# 1440
# 2024-12-24 00:00:00
# 2024-12-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 913.71 kW
# 1440
# 2024-12-25 00:00:00
# 2024-12-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 873.88 kW
# 1440
# 2024-12-26 00:00:00
# 2024-12-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 756.51 kW
# 1440
# 2024-12-27 00:00:00
# 2024-12-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 975.27 kW
# 1440
# 2024-12-28 00:00:00
# 2024-12-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 616.62 kW
# 1440
# 2024-12-29 00:00:00
# 2024-12-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 187.98 kW
# 1440
# 2024-12-30 00:00:00
# 2024-12-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 943.56 kW
# 1440
# 2024-12-31 00:00:00
# 2024-12-31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 921.03 kW
# 1440
# 2025-01-01 00:00:00
# 2025-01-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 884.62 kW
# 1440
# 2025-01-02 00:00:00
# 2025-01-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 970.27 kW
# 1440
# 2025-01-03 00:00:00
# 2025-01-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1019.46 kW
# 1440
# 2025-01-04 00:00:00
# 2025-01-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 630.56 kW
# 1440
# 2025-01-05 00:00:00
# 2025-01-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 242.98 kW
# 1440
# 2025-01-06 00:00:00
# 2025-01-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 979.64 kW
# 1440
# 2025-01-07 00:00:00
# 2025-01-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 953.55 kW
# 1440
# 2025-01-08 00:00:00
# 2025-01-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 873.96 kW
# 1440
# 2025-01-09 00:00:00
# 2025-01-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 973.07 kW
# 1440
# 2025-01-10 00:00:00
# 2025-01-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 880.94 kW
# 1440
# 2025-01-11 00:00:00
# 2025-01-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 373.02 kW
# 1440
# 2025-01-12 00:00:00
# 2025-01-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 397.45 kW
# 1440
# 2025-01-13 00:00:00
# 2025-01-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 842.42 kW
# 1440
# 2025-01-14 00:00:00
# 2025-01-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 905.97 kW
# 1440
# 2025-01-15 00:00:00
# 2025-01-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 879.33 kW
# 1440
# 2025-01-16 00:00:00
# 2025-01-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 871.02 kW
# 1440
# 2025-01-17 00:00:00
# 2025-01-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 862.89 kW
# 1440
# 2025-01-18 00:00:00
# 2025-01-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 320.13 kW
# 1440
# 2025-01-19 00:00:00
# 2025-01-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 360.63 kW
# 1440
# 2025-01-20 00:00:00
# 2025-01-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 857.41 kW
# 1440
# 2025-01-21 00:00:00
# 2025-01-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 897.76 kW
# 1440
# 2025-01-22 00:00:00
# 2025-01-22
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 858.36 kW
# 1440
# 2025-01-23 00:00:00
# 2025-01-23
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 902.07 kW
# 1440
# 2025-01-24 00:00:00
# 2025-01-24
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 858.50 kW
# 1440
# 2025-01-25 00:00:00
# 2025-01-25
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 324.50 kW
# 1440
# 2025-01-26 00:00:00
# 2025-01-26
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 210.17 kW
# 1440
# 2025-01-27 00:00:00
# 2025-01-27
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 970.94 kW
# 1440
# 2025-01-28 00:00:00
# 2025-01-28
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 913.78 kW
# 1440
# 2025-01-29 00:00:00
# 2025-01-29
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 843.99 kW
# 1440
# 2025-01-30 00:00:00
# 2025-01-30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 978.11 kW
# 1440
# 2025-01-31 00:00:00
# 2025-01-31
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1002.45 kW
# 1440
# 2025-02-01 00:00:00
# 2025-02-01
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 709.05 kW
# 1440
# 2025-02-02 00:00:00
# 2025-02-02
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Initial threshold 143.77 kW is feasible with available energy 120.00 kWh.
# Strategic threshold for the day set to: 143.77 kW
# 1440
# 2025-02-03 00:00:00
# 2025-02-03
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 991.37 kW
# 1440
# 2025-02-04 00:00:00
# 2025-02-04
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 961.76 kW
# 1440
# 2025-02-05 00:00:00
# 2025-02-05
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 893.17 kW
# 1440
# 2025-02-06 00:00:00
# 2025-02-06
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 938.98 kW
# 1440
# 2025-02-07 00:00:00
# 2025-02-07
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 980.45 kW
# 1440
# 2025-02-08 00:00:00
# 2025-02-08
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 410.43 kW
# 1440
# 2025-02-09 00:00:00
# 2025-02-09
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 192.29 kW
# 1440
# 2025-02-10 00:00:00
# 2025-02-10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 978.47 kW
# 1440
# 2025-02-11 00:00:00
# 2025-02-11
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1040.42 kW
# 1440
# 2025-02-12 00:00:00
# 2025-02-12
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 902.91 kW
# 1440
# 2025-02-13 00:00:00
# 2025-02-13
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1031.42 kW
# 1440
# 2025-02-14 00:00:00
# 2025-02-14
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 968.77 kW
# 1440
# 2025-02-15 00:00:00
# 2025-02-15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 482.73 kW
# 1440
# 2025-02-16 00:00:00
# 2025-02-16
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 187.51 kW
# 1440
# 2025-02-17 00:00:00
# 2025-02-17
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1006.48 kW
# 1440
# 2025-02-18 00:00:00
# 2025-02-18
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 1035.06 kW
# 1440
# 2025-02-19 00:00:00
# 2025-02-19
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 977.27 kW
# 1440
# 2025-02-20 00:00:00
# 2025-02-20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 987.53 kW
# 1440
# 2025-02-21 00:00:00
# 2025-02-21
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# --- Running Hybrid Simulation (Proactive Plan, Reactive Execution) ---
# Strategic threshold for the day set to: 969.88 kW
# 1440
#
#  --- Simulation Summary Over All Days ---
#             Original_peak  Reduced_peak  Reduction_kW
# Date
# 2024-04-30    1087.488333   1067.751584     19.736749
# 2024-05-01    1014.698333    993.527874     21.170459
# 2024-05-02    1077.131667   1055.232079     21.899588
# 2024-05-03    1012.855000    988.707991     24.147009
# 2024-05-04     475.508333    459.327498     16.180835
# ...                   ...           ...           ...
# 2025-02-17    1067.895000   1048.852712     19.042288
# 2025-02-18    1040.953333   1018.468853     22.484481
# 2025-02-19    1014.746667    993.920770     20.825897
# 2025-02-20    1048.626667   1024.089220     24.537447
# 2025-02-21     959.256667    936.685045     22.571622
#
# [289 rows x 3 columns]

# %%
is_zeroes = (results_summary_df['Reduction_kW'] == 0).sum()

print(is_zeroes)
# Out:
# 5

# %%
# 1. Create a boolean filter for weekdays only (Monday=0, Tuesday=1, ..., Friday=4)
is_weekday = results_summary_df.index.dayofweek < 5

# 2. Create a boolean filter for days with no reduction
is_zero_reduction = results_summary_df['Reduction_kW'] == 0

# 3. Combine the filters to find the weekdays where no reduction occurred
zero_reduction_weekdays = results_summary_df[is_weekday & is_zero_reduction]

# 4. Get the final count
num_zero_reduction_weekdays = len(zero_reduction_weekdays)

# %%
print(num_zero_reduction_weekdays)
# Out:
# 7

# %%
monthly_max_demands = results_summary_df.resample('ME').max()

monthly_max_demands = monthly_max_demands[['Original_peak', 'Reduced_peak']]
monthly_max_demands = monthly_max_demands.rename(columns = {'Original_Peak_kW' : 'Monthly_Max_Actual_kW', 'Reduced_peak' : 'Monthly_Max_Reduced_kW'})

monthly_max_demands['Month_Year'] = monthly_max_demands.index.strftime('%Y-%m')
monthly_max_demands = monthly_max_demands.set_index('Month_Year')

# monthly_max_demands['Maximum_Demand_Reduction_Factor'] = ((monthly_max_demands['Monthly_Max_Actual_kW'] - monthly_max_demands['Monthly_Max_Reduced_kW']) / monthly_max_demands['Monthly_Max_Actual_kW']) * 100

print(monthly_max_demands)
# Out:
#             Original_peak  Monthly_Max_Reduced_kW
# Month_Year
# 2024-04       1083.486667               1053.1220
# 2024-05       1092.825000               1051.1540
# 2024-06       1121.885000               1081.9130
# 2024-07       1119.426667               1077.0600
# 2024-08       1108.665000               1076.7160
# 2024-09       1078.403333               1028.9255
# 2024-10       1033.693333                987.8750
# 2024-11       1069.685000               1003.4485
# 2024-12       1000.983333                951.9780
# 2025-01        978.105000                939.5265
# 2025-02       1060.288333               1027.8255

# %%
results_summary_df.to_csv('results_summary.csv')
# monthly_max_demands.to_csv('monthly_max_demands_reduction.csv')
